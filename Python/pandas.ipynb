# %% [markdown]
# Pandas

# %%
import pandas as pd

# %%
pd.Series([1,2,3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series(['A', 'B', 'C'])
# Out:
# 0    A
# 1    B
# 2    C
# dtype: object

# %%
series1=pd.Series({'Pname': 'Shashank', 'Mobile':'841512151'})

# %%
series1.index
# Out:
# Index(['Pname', 'Mobile'], dtype='object')

# %% [markdown]
# Indexes for Series

# %%
n = pd.Series([10,20,30,40,50], index=['A','B',"C",'D','E'])
n
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %%
n['D']
# Out:
# 40

# %% [markdown]
# Updating the Series

# %%
n['D']=500

# %%
series1.max()
# Out:
# 'Shashank'

# %%
series1.min()
# Out:
# '841512151'

# %%
n.idxmax()
# Out:
# 'D'

# %% [markdown]
# DATA FRAME : Combination of of several Individual series

# %%
df=pd.DataFrame({'ProductId': [10,20,30,40],'Pname': ['A', 'B','C','D']})
df
# Out:
#    ProductId Pname
# 0         10     A
# 1         20     B
# 2         30     C
# 3         40     D

# %%
pid = pd.Series([10,20,30])
pname = pd.Series(['A','B','C'])

ind=['ProductA','ProductB','ProductC']

df = pd.DataFrame({'PId':pid,'PName':pname})
df
# Out:
#    PId PName
# 0   10     A
# 1   20     B
# 2   30     C

# %% [markdown]
# Changing Column name

# %%
df.columns= ['Id', 'Name']
df.columns
# Out:
# Index(['Id', 'Name'], dtype='object')

# %% [markdown]
# Changing Index Names

# %%
df.index= ind
df
# Out:
#           Id Name
# ProductA  10    A
# ProductB  20    B
# ProductC  30    C

# %% [markdown]
# Creating DF with Indexes & Column names

# %%
pd.DataFrame([['P1',999],['P2',6541]], index=['A','B'], columns=['Id','Price'])
# Out:
#    Id  Price
# A  P1    999
# B  P2   6541

# %% [markdown]
# Movie Lens Dataset : Pandas

# %%
df = pd.read_csv('ratings.csv', usecols=['userId']).squeeze()
type(df)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df = pd.read_csv('ratings.csv', usecols=['userId']).squeeze()
#       2 type(df)
#       3 df
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
df = pd.read_csv('ratings.csv', usecols=['userId','movieId']).squeeze()
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Datasets : PokemonDataSet

# %%
df = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\pokemon_data.csv')
df.head()
# Out:
#       Pokemon   Type
# 0   Bulbasaur  Grass
# 1     Ivysaur  Grass
# 2    Venusaur  Grass
# 3  Charmander   Fire
# 4  Charmeleon   Fire

# %%
pokemonSeries = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\pokemon_data.csv', usecols=['Pokemon']).squeeze()
pokemonSeries.head()
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: Pokemon, dtype: object

# %%
print('length',len(pokemonSeries))
print('Max:',max(pokemonSeries))
print('Min:',min(pokemonSeries))
# Out:
# length 721
# Max: Zygarde
# Min: Abomasnow

# %%
type(sorted(pokemonSeries))
# Out:
# list

# %% [markdown]
# Series to Dictionary

# %%
pokDict= dict (pokemonSeries)

# %%
pokDict
# Out:
# {0: 'Bulbasaur',
#  1: 'Ivysaur',
#  2: 'Venusaur',
#  3: 'Charmander',
#  4: 'Charmeleon',
#  5: 'Charizard',
#  6: 'Squirtle',
#  7: 'Wartortle',
#  8: 'Blastoise',
#  9: 'Caterpie',
#  10: 'Metapod',
#  11: 'Butterfree',
#  12: 'Weedle',
#  13: 'Kakuna',
#  14: 'Beedrill',
#  15: 'Pidgey',
#  16: 'Pidgeotto',
#  17: 'Pidgeot',
#  18: 'Rattata',
#  19: 'Raticate',
#  20: 'Spearow',
#  21: 'Fearow',
#  22: 'Ekans',
#  23: 'Arbok',
#  24: 'Pikachu',
#  25: 'Raichu',
#  26: 'Sandshrew',
#  27: 'Sandslash',
#  28: 'Nidoran',
#  29: 'Nidorina',
#  30: 'Nidoqueen',
#  31: 'Nidoran♂',
#  32: 'Nidorino',
#  33: 'Nidoking',
#  34: 'Clefairy',
#  35: 'Clefable',
#  36: 'Vulpix',
#  37: 'Ninetales',
#  38: 'Jigglypuff',
#  39: 'Wigglytuff',
#  40: 'Zubat',
#  41: 'Golbat',
#  42: 'Oddish',
#  43: 'Gloom',
#  44: 'Vileplume',
#  45: 'Paras',
#  46: 'Parasect',
#  47: 'Venonat',
#  48: 'Venomoth',
#  49: 'Diglett',
#  50: 'Dugtrio',
#  51: 'Meowth',
#  52: 'Persian',
#  53: 'Psyduck',
# ...

# %% [markdown]
# Sorting

# %%
pokemonSeries.sort_values(ignore_index=True,ascending=False,).head(7)
# Out:
# 0      Zygarde
# 1     Zweilous
# 2        Zubat
# 3        Zorua
# 4      Zoroark
# 5    Zigzagoon
# 6       Zekrom
# Name: Pokemon, dtype: object

# %% [markdown]
# Pokemon as Index

# %%
typeSeries = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\pokemon_data.csv',index_col=['Pokemon']).squeeze()
typeSeries
# Out:
# Pokemon
# Bulbasaur       Grass
# Ivysaur         Grass
# Venusaur        Grass
# Charmander       Fire
# Charmeleon       Fire
#                ...
# Yveltal          Dark
# Zygarde        Dragon
# Diancie          Rock
# Hoopa         Psychic
# Volcanion        Fire
# Name: Type, Length: 721, dtype: object

# %% [markdown]
# Row Label Indexing

# %%
typeSeries.sort_index()
# Out:
# Pokemon
# Abomasnow      Grass
# Abra         Psychic
# Absol           Dark
# Accelgor         Bug
# Aegislash      Steel
#               ...
# Zoroark         Dark
# Zorua           Dark
# Zubat         Poison
# Zweilous        Dark
# Zygarde       Dragon
# Name: Type, Length: 721, dtype: object

# %%
for i,v in enumerate(typeSeries):
    print(i,v)
# Out:
# 0 Grass
# 1 Grass
# 2 Grass
# 3 Fire
# 4 Fire
# 5 Fire
# 6 Water
# 7 Water
# 8 Water
# 9 Bug
# 10 Bug
# 11 Bug
# 12 Bug
# 13 Bug
# 14 Bug
# 15 Normal
# 16 Normal
# 17 Normal
# 18 Normal
# 19 Normal
# 20 Normal
# 21 Normal
# 22 Poison
# 23 Poison
# 24 Electric
# 25 Electric
# 26 Ground
# 27 Ground
# 28 Poison
# 29 Poison
# 30 Poison
# 31 Poison
# 32 Poison
# 33 Poison
# 34 Fairy
# 35 Fairy
# 36 Fire
# 37 Fire
# 38 Normal
# 39 Normal
# 40 Poison
# 41 Poison
# 42 Grass
# 43 Grass
# 44 Grass
# 45 Bug
# 46 Bug
# 47 Bug
# 48 Bug
# 49 Ground
# 50 Ground
# 51 Normal
# 52 Normal
# 53 Water
# 54 Water
# 55 Fighting
# 56 Fighting
# 57 Fire
# 58 Fire
# 59 Water
# 60 Water
# 61 Water
# 62 Psychic
# 63 Psychic
# 64 Psychic
# 65 Fighting
# 66 Fighting
# 67 Fighting
# 68 Grass
# 69 Grass
# 70 Grass
# 71 Water
# 72 Water
# 73 Rock
# 74 Rock
# 75 Rock
# 76 Fire
# 77 Fire
# 78 Water
# 79 Water
# 80 Electric
# 81 Electric
# 82 Normal
# 83 Normal
# 84 Normal
# 85 Water
# 86 Water
# 87 Poison
# 88 Poison
# ...

# %%
'Abra' in typeSeries.index
# Out:
# True

# %%
pokemonSeries[0:5]
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: Pokemon, dtype: object

# %%
pokemonSeries[[5,9,45]]
# Out:
# 5     Charizard
# 9      Caterpie
# 45        Paras
# Name: Pokemon, dtype: object

# %%
pokemonSeries[[0,2,720]] = ['Shashank Raj','Novil', 'Ram']

# %%
pokemonSeries
# Out:
# 0      Shashank Raj
# 1           Ivysaur
# 2             Novil
# 3        Charmander
# 4        Charmeleon
#            ...
# 716         Yveltal
# 717         Zygarde
# 718         Diancie
# 719           Hoopa
# 720             Ram
# Name: Pokemon, Length: 721, dtype: object

# %%
typeSeries.get([0,6,51,720],'Skipped')
# Out:
# Pokemon
# Bulbasaur     Grass
# Squirtle      Water
# Meowth       Normal
# Volcanion      Fire
# Name: Type, dtype: object

# %% [markdown]
# Apply to all values

# %%
typeSeries.apply(len)
# Out:
# Pokemon
# Bulbasaur     5
# Ivysaur       5
# Venusaur      5
# Charmander    4
# Charmeleon    4
#              ..
# Yveltal       4
# Zygarde       6
# Diancie       4
# Hoopa         7
# Volcanion     4
# Name: Type, Length: 721, dtype: int64

# %% [markdown]
# JamesBond Dataset

# %% [markdown]
# create index column with first values
# apply a functionality ,
# if year is from 1960 to 1975, Output: "Movie Hit"
#                 1975 to 2000, 'Flop'
#             else 'Avg'

# %%
dfJames = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\jamesbond_user.csv', index_col=['Film'])
jamesSeries = dfJames

# %%
def ratings(x):
    rating = None
    if 1960<= x < 1975:
        rating='Movie Hit'
    
    elif x >1975 and x <=2000:
        rating='Movie Flop'

    else:
        rating='Movie Avg'

    return rating

jamesSeries['Year'].apply(ratings)

newdict=dict(jamesSeries['Year'].apply(ratings))

# %%
dic = dict(jamesSeries['Year'].map(ratings))

# %%
dic
# Out:
# {'Dr. No': 'Movie Hit',
#  'From Russia with Love': 'Movie Hit',
#  'Goldfinger': 'Movie Hit',
#  'Thunderball': 'Movie Hit',
#  'Casino Royale': Film
#  Casino Royale    Movie Hit
#  Casino Royale    Movie Avg
#  Name: Year, dtype: object,
#  'You Only Live Twice': 'Movie Hit',
#  "On Her Majesty's Secret Service": 'Movie Hit',
#  'Diamonds Are Forever': 'Movie Hit',
#  'Live and Let Die': 'Movie Hit',
#  'The Man with the Golden Gun': 'Movie Hit',
#  'The Spy Who Loved Me': 'Movie Flop',
#  'Moonraker': 'Movie Flop',
#  'For Your Eyes Only': 'Movie Flop',
#  'Never Say Never Again': 'Movie Flop',
#  'Octopussy': 'Movie Flop',
#  'A View to a Kill': 'Movie Flop',
#  'The Living Daylights': 'Movie Flop',
#  'Licence to Kill': 'Movie Flop',
#  'GoldenEye': 'Movie Flop',
#  'Tomorrow Never Dies': 'Movie Flop',
#  'The World Is Not Enough': 'Movie Flop',
#  'Die Another Day': 'Movie Avg',
#  'Quantum of Solace': 'Movie Avg',
#  'Skyfall': 'Movie Avg',
#  'Spectre': 'Movie Avg'}

# %%
myDict = {'Water':'Happy', 'Fire': "Angry"}

# typeSeries.map(myDict)

# %% [markdown]
# Tushar: DataFrame

# %%
df = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\pokemon_data.csv')
df
# Out:
#         Pokemon     Type
# 0     Bulbasaur    Grass
# 1       Ivysaur    Grass
# 2      Venusaur    Grass
# 3    Charmander     Fire
# 4    Charmeleon     Fire
# ..          ...      ...
# 716     Yveltal     Dark
# 717     Zygarde   Dragon
# 718     Diancie     Rock
# 719       Hoopa  Psychic
# 720   Volcanion     Fire
#
# [721 rows x 2 columns]

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=721, step=1),
#  Index(['Pokemon', 'Type'], dtype='object')]

# %%
df.columns
# Out:
# Index(['Pokemon', 'Type'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 721 entries, 0 to 720
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Pokemon  721 non-null    object
#  1   Type     721 non-null    object
# dtypes: object(2)
# memory usage: 11.4+ KB

# %% [markdown]
# Selecting specific Column

# %%
df[['Pokemon','Type']]
# Out:
#         Pokemon     Type
# 0     Bulbasaur    Grass
# 1       Ivysaur    Grass
# 2      Venusaur    Grass
# 3    Charmander     Fire
# 4    Charmeleon     Fire
# ..          ...      ...
# 716     Yveltal     Dark
# 717     Zygarde   Dragon
# 718     Diancie     Rock
# 719       Hoopa  Psychic
# 720   Volcanion     Fire
#
# [721 rows x 2 columns]

# %% [markdown]
# DataSet : NBA

# %%
df = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\NbaInfo.csv')
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df[['Name','Age']]
# Out:
#               Name   Age
# 0    Avery Bradley  25.0
# 1      Jae Crowder  25.0
# 2     John Holland  27.0
# 3      R.J. Hunter  22.0
# 4    Jonas Jerebko  29.0
# ..             ...   ...
# 453   Shelvin Mack  26.0
# 454      Raul Neto  24.0
# 455   Tibor Pleiss  26.0
# 456    Jeff Withey  26.0
# 457            NaN   NaN
#
# [458 rows x 2 columns]

# %% [markdown]
# Inserting Column at the end of the df

# %%
df['Email'] = 'user@gmail.com'
df
# Out:
#               Name  WeightUser            Team  Number Position   Age Height  \
# 0    Avery Bradley          80  Boston Celtics     0.0       PG  25.0    6-2
# 1      Jae Crowder          80  Boston Celtics    99.0       SF  25.0    6-6
# 2     John Holland          80  Boston Celtics    30.0       SG  27.0    6-5
# 3      R.J. Hunter          80  Boston Celtics    28.0       SG  22.0    6-5
# 4    Jonas Jerebko          80  Boston Celtics     8.0       PF  29.0   6-10
# ..             ...         ...             ...     ...      ...   ...    ...
# 453   Shelvin Mack          80       Utah Jazz     8.0       PG  26.0    6-3
# 454      Raul Neto          80       Utah Jazz    25.0       PG  24.0    6-1
# 455   Tibor Pleiss          80       Utah Jazz    21.0        C  26.0    7-3
# 456    Jeff Withey          80       Utah Jazz    24.0        C  26.0    7-0
# 457            NaN          80             NaN     NaN      NaN   NaN    NaN
#
# ...

# %% [markdown]
# Insert at Specified position

# %%
df.insert(loc=1,column='WeightUser',value=80)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[299], line 1
# ----> 1 df.insert(loc=1,column='WeightUser',value=80)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:4817, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4811     raise ValueError(
#    4812         "Cannot specify 'allow_duplicates=True' when "
#    4813         "'self.flags.allows_duplicate_labels' is False."
#    4814     )
#    4815 if not allow_duplicates and column in self.columns:
#    4816     # Should this be a different kind of error??
# -> 4817     raise ValueError(f"cannot insert {column}, already exists")
#    4818 if not isinstance(loc, int):
#    4819     raise TypeError("loc must be int")
#
# ValueError: cannot insert WeightUser, already exists

# %%
df
# Out:
#               Name  WeightUser            Team  Number Position   Age Height  \
# 0    Avery Bradley          80  Boston Celtics     0.0       PG  25.0    6-2
# 1      Jae Crowder          80  Boston Celtics    99.0       SF  25.0    6-6
# 2     John Holland          80  Boston Celtics    30.0       SG  27.0    6-5
# 3      R.J. Hunter          80  Boston Celtics    28.0       SG  22.0    6-5
# 4    Jonas Jerebko          80  Boston Celtics     8.0       PF  29.0   6-10
# ..             ...         ...             ...     ...      ...   ...    ...
# 453   Shelvin Mack          80       Utah Jazz     8.0       PG  26.0    6-3
# 454      Raul Neto          80       Utah Jazz    25.0       PG  24.0    6-1
# 455   Tibor Pleiss          80       Utah Jazz    21.0        C  26.0    7-3
# 456    Jeff Withey          80       Utah Jazz    24.0        C  26.0    7-0
# 457            NaN          80             NaN     NaN      NaN   NaN    NaN
#
# ...

# %% [markdown]
# Adding Values

# %%
df['newAge']= df['Age']+4
df
# Out:
#               Name  WeightUser            Team  Number Position   Age Height  \
# 0    Avery Bradley          80  Boston Celtics     0.0       PG  25.0    6-2
# 1      Jae Crowder          80  Boston Celtics    99.0       SF  25.0    6-6
# 2     John Holland          80  Boston Celtics    30.0       SG  27.0    6-5
# 3      R.J. Hunter          80  Boston Celtics    28.0       SG  22.0    6-5
# 4    Jonas Jerebko          80  Boston Celtics     8.0       PF  29.0   6-10
# ..             ...         ...             ...     ...      ...   ...    ...
# 453   Shelvin Mack          80       Utah Jazz     8.0       PG  26.0    6-3
# 454      Raul Neto          80       Utah Jazz    25.0       PG  24.0    6-1
# 455   Tibor Pleiss          80       Utah Jazz    21.0        C  26.0    7-3
# 456    Jeff Withey          80       Utah Jazz    24.0        C  26.0    7-0
# 457            NaN          80             NaN     NaN      NaN   NaN    NaN
#
# ...

# %% [markdown]
# Value Counts

# %%
df['Team'].value_counts()
df.value_counts(subset='Team')

df.value_counts(subset='Team',normalize=True)
# Out:
# Team
# New Orleans Pelicans      0.041575
# Memphis Grizzlies         0.039387
# New York Knicks           0.035011
# Milwaukee Bucks           0.035011
# Atlanta Hawks             0.032823
# Utah Jazz                 0.032823
# Toronto Raptors           0.032823
# San Antonio Spurs         0.032823
# Sacramento Kings          0.032823
# Portland Trail Blazers    0.032823
# Phoenix Suns              0.032823
# Philadelphia 76ers        0.032823
# Oklahoma City Thunder     0.032823
# Boston Celtics            0.032823
# Miami Heat                0.032823
# Los Angeles Lakers        0.032823
# Los Angeles Clippers      0.032823
# Indiana Pacers            0.032823
# Houston Rockets           0.032823
# Golden State Warriors     0.032823
# Detroit Pistons           0.032823
# Denver Nuggets            0.032823
# Dallas Mavericks          0.032823
# Cleveland Cavaliers       0.032823
# Chicago Bulls             0.032823
# Charlotte Hornets         0.032823
# ...

# %% [markdown]
# NaaN Values

# %%
df['Name'].hasnans
# Out:
# True

# %%
df.dropna(how='all')
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary  newAge
# 0                Texas  7730337.0    29.0
# ...

# %%
df.dropna(subset=['College','Salary'])
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary  newAge
# 0            Texas  7730337.0    29.0
# ...

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary  newAge
# 0                Texas  7730337.0    29.0
# ...

# %% [markdown]
# Fill Naan

# %%
df['Salary'] = df['Salary'].fillna(0)

# %%
df['College'] = df['College'].fillna('Futurense')
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# Sorting

# %%
df.sort_values(by=['Team','Name'], ascending=[False,True], na_position='first')
# Out:
#                  Name                Team  Number Position   Age Height  \
# 457               NaN                 NaN     NaN      NaN   NaN    NaN
# 368     Alan Anderson  Washington Wizards     6.0       SG  33.0    6-6
# 369      Bradley Beal  Washington Wizards     3.0       SG  22.0    6-5
# 372       Drew Gooden  Washington Wizards    90.0       PF  34.0   6-10
# 380    Garrett Temple  Washington Wizards    17.0       SG  30.0    6-6
# ..                ...                 ...     ...      ...   ...    ...
# 315      Paul Millsap       Atlanta Hawks     4.0       PF  31.0    6-8
# 320   Thabo Sefolosha       Atlanta Hawks    25.0       SF  32.0    6-7
# 321    Tiago Splitter       Atlanta Hawks    11.0        C  31.0   6-11
# 310  Tim Hardaway Jr.       Atlanta Hawks    10.0       SG  24.0    6-6
# 322    Walter Tavares       Atlanta Hawks    22.0        C  24.0    7-3
#
#      Weight         College      Salary
# 457     NaN       Futurense         0.0
# ...

# %% [markdown]
# Type Change

# %%
df['Salary'].astype(int)
# Out:
# 0      7730337
# 1      6796117
# 2            0
# 3      1148640
# 4      5000000
#         ...
# 453    2433333
# 454     900000
# 455    2900000
# 456     947276
# 457          0
# Name: Salary, Length: 458, dtype: int32

# %%
df['Age']=df['Age'].fillna(0)
df['Age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 458 entries, 0 to 457
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 458 non-null    float64
# dtypes: float64(1)
# memory usage: 3.7 KB

# %%
df['Age']= df['Age'].astype(int)

# %%
df['Age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 458 entries, 0 to 457
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 458 non-null    int32
# dtypes: int32(1)
# memory usage: 1.9 KB

# %% [markdown]
# Unique

# %%
print(df['Team'].nunique())
df['Team'].unique()
# Out:
# 30
# ['Boston Celtics', 'Brooklyn Nets', 'New York Knicks', 'Philadelphia 76ers', 'Toronto Raptors', ..., 'Minnesota Timberwolves', 'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz', NaN]
# Length: 31
# Categories (30, object): ['Atlanta Hawks', 'Boston Celtics', 'Brooklyn Nets', 'Charlotte Hornets', ..., 'San Antonio Spurs', 'Toronto Raptors', 'Utah Jazz', 'Washington Wizards']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    category
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    category
#  4   Age       458 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   458 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: category(2), float64(3), int32(1), object(3)
# memory usage: 25.8+ KB

# %%
df['Team']= df['Team'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    category
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    category
#  4   Age       458 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   458 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: category(2), float64(3), int32(1), object(3)
# memory usage: 25.8+ KB

# %%
df['Position'] = df['Position'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    category
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    category
#  4   Age       458 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   458 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: category(2), float64(3), int32(1), object(3)
# memory usage: 25.8+ KB

# %%
df['Age'].nunique()
# Out:
# 23

# %% [markdown]
# ### Question
# - index=Rank
# - optimize the DF from the columns
# - Calculate how many companies are present?
# - Unique companies?
# - Total revenue generated for energy sector?
# - Total no of count of employees from technology or telecommunication sector?

# %%
df = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\fortune_data.csv', index_col='Rank')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Company    1000 non-null   object
#  1   Sector     1000 non-null   object
#  2   Industry   1000 non-null   object
#  3   Location   1000 non-null   object
#  4   Revenue    1000 non-null   int64
#  5   Profits    1000 non-null   int64
#  6   Employees  1000 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 62.5+ KB

# %%
df.head()
# Out:
#                  Company       Sector  \
# Rank
# 1                Walmart    Retailing
# 2            Exxon Mobil       Energy
# 3                  Apple   Technology
# 4     Berkshire Hathaway   Financials
# 5               McKesson  Health Care
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600
# 3       53394     110000
# 4       24083     331000
# 5        1476      70400

# %%
df['Sector'] = df['Sector'].astype('category')

# %%
df['Industry'] = df['Industry'].astype('category')

# %%
df['Location'] = df['Location'].astype(object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Company    1000 non-null   object
#  1   Sector     1000 non-null   category
#  2   Industry   1000 non-null   category
#  3   Location   1000 non-null   object
#  4   Revenue    1000 non-null   int64
#  5   Profits    1000 non-null   int64
#  6   Employees  1000 non-null   int64
# dtypes: category(2), int64(3), object(2)
# memory usage: 52.2+ KB

# %%
df['Company'].count()
# Out:
# 1000

# %%
df['Company'].nunique()
# Out:
# 996

# %% [markdown]
# Energy Sector- Total Revenue

# %%
df[df['Sector']=='Energy']['Revenue'].sum()
# Out:
# 1517809

# %% [markdown]
# Count of Employees

# %%
df[(df['Sector'] == 'Technology') | (df['Sector'] == 'Telecommunications')]['Employees'].sum()
# Out:
# 4411417

# %%
df[(df['Sector'] == 'Technology') | (df['Sector'] == 'Telecommunications')].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 3 to 990
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Company    117 non-null    object
#  1   Sector     117 non-null    category
#  2   Industry   117 non-null    category
#  3   Location   117 non-null    object
#  4   Revenue    117 non-null    int64
#  5   Profits    117 non-null    int64
#  6   Employees  117 non-null    int64
# dtypes: category(2), int64(3), object(2)
# memory usage: 9.0+ KB

# %% [markdown]
# New Class

# %%
df = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\NbaInfo.csv')
df.info()
df=df.dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
df['Rank_salary'] = df['Salary'].rank().astype(int)
df.sort_values(by='Salary', ascending=False, inplace=True)
df
# Out:
#                 Name                   Team  Number Position   Age Height  \
# 33   Carmelo Anthony        New York Knicks     7.0       SF  32.0    6-8
# 339       Chris Bosh             Miami Heat     1.0       PF  32.0   6-11
# 100       Chris Paul   Los Angeles Clippers     3.0       PG  31.0    6-0
# 414     Kevin Durant  Oklahoma City Thunder    35.0       SF  27.0    6-9
# 164     Derrick Rose          Chicago Bulls     1.0       PG  27.0    6-3
# ..               ...                    ...     ...      ...   ...    ...
# 92        Jeff Ayres   Los Angeles Clippers    19.0       PF  29.0    6-9
# 175     Jordan McRae    Cleveland Cavaliers    12.0       SG  25.0    6-5
# 135    Alan Williams           Phoenix Suns    15.0        C  23.0    6-8
# 291  Orlando Johnson   New Orleans Pelicans     0.0       SG  27.0    6-5
# 130     Phil Pressey           Phoenix Suns    25.0       PG  25.0   5-11
#
#      Weight           College      Salary  Rank_salary
# ...

# %% [markdown]
# EmployeeInfo : Time Dataset

# %%
df = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\EmployeesInfo.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df['First Name'].hasnans
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %% [markdown]
# Changing DataType

# %%
df['Start Date'] = pd.to_datetime(df['Start Date'])

# %%
df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])

# %%
df['Senior Management'] = (df['Senior Management']).astype(bool)

# %%
df['Team'] = (df['Team']).astype('category')

# %%
df['Gender'] = (df['Gender']).astype('category')

# %% [markdown]
# Comparison

# %%
df[df['Gender']=='Male']
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2023-02-01 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2023-02-01 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2023-02-01 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2023-02-01 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2023-02-01 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2023-02-01 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2023-02-01 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2023-02-01 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2023-02-01 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2023-02-01 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
df[df['Start Date'] < '1981']
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 10      Louise  Female 1980-08-12 2023-02-01 09:01:00   63241   15.132
# 12     Brandon    Male 1980-12-01 2023-02-01 01:08:00  112807   17.492
# 43     Marilyn  Female 1980-12-07 2023-02-01 03:16:00   73524    5.207
# 45       Roger    Male 1980-04-17 2023-02-01 11:32:00   88010   13.886
# 49       Chris     NaN 1980-01-24 2023-02-01 12:13:00  113590    3.055
# 82      Steven    Male 1980-03-30 2023-02-01 21:20:00   35095    8.379
# 154    Rebecca  Female 1980-11-15 2023-02-01 04:13:00   85730    5.359
# 213     Evelyn  Female 1980-05-24 2023-02-01 23:10:00   81673   15.364
# 272       Fred    Male 1980-02-20 2023-02-01 02:25:00   74129   18.225
# 303       Joan     NaN 1980-07-25 2023-02-01 12:22:00   38712    3.657
# 384       Jack    Male 1980-12-24 2023-02-01 22:58:00  106995   15.723
# 423    Deborah  Female 1980-11-25 2023-02-01 04:33:00   46953   17.436
# ...

# %% [markdown]
# ### Q
# - Filter Data, Whose firstname is 'Louise' and belongs to senior Management
# - Filter Data, The no of females who has been hired after 1990
# - Whose salary is from 10,000 to 20,000

# %%
df[(df['First Name']== 'Louise' ) & (df['Senior Management']== True)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 10      Louise  Female 1980-08-12 2023-02-01 09:01:00   63241   15.132
# 441     Louise  Female 2003-05-13 2023-02-01 09:47:00   46666    1.886
#
#      Senior Management                  Team
# 10                True                   NaN
# 441               True  Business Development

# %%
df[(df['Gender'] == 'Female') & (df['Start Date'] > '1990-01-01')]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2023-02-01 11:17:00  130590   11.858
# 7          NaN  Female 2015-07-20 2023-02-01 10:43:00   45906   11.598
# 8       Angela  Female 2005-11-22 2023-02-01 06:29:00   95570   18.523
# 9      Frances  Female 2002-08-08 2023-02-01 06:51:00  139852    7.524
# 11       Julie  Female 1997-10-26 2023-02-01 15:19:00  102508   12.637
# ..         ...     ...        ...                 ...     ...      ...
# 984      Maria  Female 2011-10-15 2023-02-01 16:53:00   43455   13.040
# 987     Gloria  Female 2014-12-08 2023-02-01 05:08:00  136709   10.331
# 988      Alice  Female 2004-10-05 2023-02-01 09:34:00   47638   11.209
# 991       Rose  Female 2002-08-25 2023-02-01 05:12:00  134505   11.051
# 993       Tina  Female 1997-05-15 2023-02-01 15:53:00   56450   19.040
#
#      Senior Management                  Team
# 2                False               Finance
# ...

# %%
df[(df['Salary'] >=10000) & (df['Salary'] <=70000)]

df[df['Salary'].between(10000,70000)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2023-02-01 06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17 2023-02-01 16:20:00   65476   10.012
# 7          NaN  Female 2015-07-20 2023-02-01 10:43:00   45906   11.598
# 10      Louise  Female 1980-08-12 2023-02-01 09:01:00   63241   15.132
# 14    Kimberly  Female 1999-01-14 2023-02-01 07:13:00   41426   14.543
# ..         ...     ...        ...                 ...     ...      ...
# 988      Alice  Female 2004-10-05 2023-02-01 09:34:00   47638   11.209
# 989     Justin     NaN 1991-02-10 2023-02-01 16:58:00   38344    3.794
# 993       Tina  Female 1997-05-15 2023-02-01 15:53:00   56450   19.040
# 996    Phillip    Male 1984-01-31 2023-02-01 06:30:00   42392   19.675
# 998      Larry    Male 2013-04-20 2023-02-01 16:45:00   60500   11.985
#
#      Senior Management                  Team
# 1                 True                   NaN
# ...

# %% [markdown]
# *isin* Operator

# %%
df['Team'].isin(['Human Resource','Legal','Product'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997     True
# 998    False
# 999    False
# Name: Team, Length: 1000, dtype: bool

# %% [markdown]
# No of Null Value

# %%
df['First Name'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: First Name, Length: 1000, dtype: bool

# %% [markdown]
# Who have a Team and belong to Female Gender

# %%
df[(df['Team'].isna()) & (df['Gender'] == 'Female')]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 10      Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 139        NaN  Female   10/3/1990         1:08 AM  132373   10.527
# 382        NaN  Female   4/18/1996         3:57 PM  107024   12.182
# 434      Joyce  Female    2/7/1995         7:38 AM   50701   14.227
# 512      Wanda  Female    4/6/1993         3:11 AM   78883   19.695
# 567        NaN  Female    4/1/1980         8:04 PM   48141   12.605
# 573   Kimberly  Female  12/30/1981         4:51 AM   81800    5.435
# 626        NaN  Female   4/13/1997         8:03 AM  131755    2.930
# 684      Alice  Female   1/21/2016         5:07 PM  117787   10.485
# 774        NaN  Female   6/18/2000         7:36 AM  106428   10.867
# 794     Nicole  Female    3/1/2004         5:17 PM   44021   10.286
# 853    Mildred  Female    4/6/2007        10:06 PM  139284   11.390
# 951        NaN  Female   9/14/2010         5:19 AM  143638    9.662
#
# ...

# %%
df[df['Team'] != 'NaN']
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df[df['Team'].isna()].count()
# Out:
# First Name           34
# Gender               39
# Start Date           43
# Last Login Time      43
# Salary               43
# Bonus %              43
# Senior Management    34
# Team                  0
# dtype: int64

# %%
df[df['Team'].isnull()].count()
# Out:
# First Name           34
# Gender               39
# Start Date           43
# Last Login Time      43
# Salary               43
# Bonus %              43
# Senior Management    34
# Team                  0
# dtype: int64

# %% [markdown]
# Duplicates

# %%
df[df.duplicated()]

# df.duplicated(subset=['First Name'])
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %%
df[df.duplicated(subset=['First Name'])]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 327      Aaron    Male   1/29/1994         6:48 PM   58755    5.097
# 440      Aaron    Male   7/22/1990         2:53 PM   52119   11.343
# 937      Aaron     NaN   1/22/1986         7:39 PM   63126   18.424
# 141       Adam    Male  12/24/1990         8:57 PM  110194   14.727
# 302       Adam    Male    7/5/2007        11:59 AM   71276    5.027
# ..         ...     ...         ...             ...     ...      ...
# 902        NaN    Male   5/23/2001         7:52 PM  103877    6.322
# 925        NaN  Female   8/23/2000         4:19 PM   95866   19.388
# 946        NaN  Female   9/15/1985         1:50 AM  133472   16.941
# 947        NaN    Male   7/30/2012         3:07 PM  107351    5.329
# 951        NaN  Female   9/14/2010         5:19 AM  143638    9.662
#
#     Senior Management             Team
# 327              True        Marketing
# 440              True  Client Services
# ...

# %%
df.drop_duplicates(subset='First Name',keep='first')
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male   2/17/2012        10:20 AM   61602   11.849
# 137       Adam    Male   5/21/2011         1:45 AM   95327   15.120
# 300       Alan    Male   6/26/1988         3:54 AM  111786    3.592
# 372     Albert    Male    2/1/1997         4:20 PM   67827   19.717
# 988      Alice  Female   10/5/2004         9:34 AM   47638   11.209
# ..         ...     ...         ...             ...     ...      ...
# 433      Wanda  Female   7/20/2008         1:44 PM   65362    7.132
# 177      Wayne    Male    4/7/2012         8:00 AM  102652   14.085
# 820    William    Male  11/18/1993        12:27 PM   54058    5.182
# 450     Willie    Male   8/22/2009         1:03 PM   55038   19.691
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
#
#     Senior Management             Team
# 101              True        Marketing
# 137             False     Distribution
# ...

# %% [markdown]
# Index

# %%
dummyDf = df.set_index(['First Name'])
# dummyDf = df.set_index(['First Name', 'Gender'])
dummyDf.reset_index(drop=True,)
dummyDf
# Out:
#             Gender Start Date Last Login Time  Salary  Bonus %  \
# First Name
# Aaron         Male  2/17/2012        10:20 AM   61602   11.849
# Aaron         Male  1/29/1994         6:48 PM   58755    5.097
# Aaron         Male  7/22/1990         2:53 PM   52119   11.343
# Aaron          NaN  1/22/1986         7:39 PM   63126   18.424
# Adam          Male  5/21/2011         1:45 AM   95327   15.120
# ...            ...        ...             ...     ...      ...
# NaN           Male  5/23/2001         7:52 PM  103877    6.322
# NaN         Female  8/23/2000         4:19 PM   95866   19.388
# NaN         Female  9/15/1985         1:50 AM  133472   16.941
# NaN           Male  7/30/2012         3:07 PM  107351    5.329
# NaN         Female  9/14/2010         5:19 AM  143638    9.662
#
#            Senior Management             Team
# First Name
# Aaron                   True        Marketing
# Aaron                   True        Marketing
# ...

# %% [markdown]
# Row Label Indexing

# %%
dfNba = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\NbaInfo.csv')
df=dfNba

# %%
df=df.dropna()

# %%
df=df.set_index('Name')

# %%
df.loc['Avery Bradley']
# Out:
# Team        Boston Celtics
# Number                 0.0
# Position                PG
# Age                   25.0
# Height                 6-2
# Weight               180.0
# College              Texas
# Salary           7730337.0
# Name: Avery Bradley, dtype: object

# %%
df.loc['Avery Bradley', 'Team']
# Out:
# 'Boston Celtics'

# %%
df.loc['Avery Bradley', 'Team': 'Age']
# Out:
# Team        Boston Celtics
# Number                 0.0
# Position                PG
# Age                   25.0
# Name: Avery Bradley, dtype: object

# %%
df.loc['Aaron Brooks': 'Al Horford', 'Team': 'Age']
# Out:
#                                Team  Number Position   Age
# Name
# Aaron Brooks          Chicago Bulls     0.0       PG  31.0
# Jimmy Butler          Chicago Bulls    21.0       SG  26.0
# Mike Dunleavy         Chicago Bulls    34.0       SG  35.0
# Taj Gibson            Chicago Bulls    22.0       PF  30.0
# Justin Holiday        Chicago Bulls     7.0       SG  27.0
# ...                             ...     ...      ...   ...
# David West        San Antonio Spurs    30.0       PF  35.0
# Kent Bazemore         Atlanta Hawks    24.0       SF  26.0
# Tim Hardaway Jr.      Atlanta Hawks    10.0       SG  24.0
# Kirk Hinrich          Atlanta Hawks    12.0       SG  35.0
# Al Horford            Atlanta Hawks    15.0        C  30.0
#
# [130 rows x 4 columns]

# %%
df.iloc[2,:4]
# Out:
# Team        Boston Celtics
# Number                28.0
# Position                SG
# Age                   22.0
# Name: R.J. Hunter, dtype: object

# %% [markdown]
# Drop

# %%
# df.drop('Team', axis=1)
dfTeam=df.pop('Team')

# %%
# df['Team'] = dfNba['Team']

# %%
df.insert(2,value=dfTeam,column='Team')

# %%
df
# Out:
#                Number Position            Team   Age Height  Weight  \
# Name
# Avery Bradley     0.0       PG  Boston Celtics  25.0    6-2   180.0
# Jae Crowder      99.0       SF  Boston Celtics  25.0    6-6   235.0
# R.J. Hunter      28.0       SG  Boston Celtics  22.0    6-5   185.0
# Jordan Mickey    55.0       PF  Boston Celtics  21.0    6-8   235.0
# Kelly Olynyk     41.0        C  Boston Celtics  25.0    7-0   238.0
# ...               ...      ...             ...   ...    ...     ...
# Rodney Hood       5.0       SG       Utah Jazz  23.0    6-8   206.0
# Chris Johnson    23.0       SF       Utah Jazz  26.0    6-6   206.0
# Trey Lyles       41.0       PF       Utah Jazz  20.0   6-10   234.0
# Shelvin Mack      8.0       PG       Utah Jazz  26.0    6-3   203.0
# Jeff Withey      24.0        C       Utah Jazz  26.0    7-0   231.0
#
#                      College     Salary
# Name
# Avery Bradley          Texas  7730337.0
# Jae Crowder        Marquette  6796117.0
# ...

# %% [markdown]
# Sampling

# %%
df.sample(frac=0.01)
# Out:
#                      Number Position                   Team   Age Height  \
# Name
# Reggie Bullock         25.0       SF        Detroit Pistons  25.0    6-7
# Marreese Speights       5.0        C  Golden State Warriors  28.0   6-10
# Ryan Kelly              4.0       PF     Los Angeles Lakers  25.0   6-11
# Johnny O'Bryant III    77.0       PF        Milwaukee Bucks  23.0    6-9
#
#                      Weight         College     Salary
# Name
# Reggie Bullock        205.0  North Carolina  1252440.0
# Marreese Speights     255.0         Florida  3815000.0
# Ryan Kelly            230.0            Duke  1724250.0
# Johnny O'Bryant III   257.0             LSU   845059.0

# %% [markdown]
# Greatest/Smallest

# %%
df['Weight'].sort_values(ascending=False)[:3]

# df.nlargest(3,columns='Weight')
# Out:
# Name
# Andre Drummond    279.0
# Brook Lopez       275.0
# Jahlil Okafor     275.0
# Name: Weight, dtype: float64

# %%
df.nsmallest(3,columns='Weight')
# Out:
#               Number Position                  Team   Age Height  Weight  \
# Name
# Aaron Brooks     0.0       PG         Chicago Bulls  31.0    6-0   161.0
# Bryce Cotton     8.0       PG     Memphis Grizzlies  23.0    6-1   165.0
# Tim Frazier      2.0       PG  New Orleans Pelicans  25.0    6-1   170.0
#
#                  College     Salary
# Name
# Aaron Brooks      Oregon  2250000.0
# Bryce Cotton  Providence   700902.0
# Tim Frazier   Penn State   845059.0

# %%
df.where(df['Age']==22)
# Out:
#                Number Position            Team   Age Height  Weight  \
# Name
# Avery Bradley     NaN      NaN             NaN   NaN    NaN     NaN
# Jae Crowder       NaN      NaN             NaN   NaN    NaN     NaN
# R.J. Hunter      28.0       SG  Boston Celtics  22.0    6-5   185.0
# Jordan Mickey     NaN      NaN             NaN   NaN    NaN     NaN
# Kelly Olynyk      NaN      NaN             NaN   NaN    NaN     NaN
# ...               ...      ...             ...   ...    ...     ...
# Rodney Hood       NaN      NaN             NaN   NaN    NaN     NaN
# Chris Johnson     NaN      NaN             NaN   NaN    NaN     NaN
# Trey Lyles        NaN      NaN             NaN   NaN    NaN     NaN
# Shelvin Mack      NaN      NaN             NaN   NaN    NaN     NaN
# Jeff Withey       NaN      NaN             NaN   NaN    NaN     NaN
#
#                      College     Salary
# Name
# Avery Bradley            NaN        NaN
# Jae Crowder              NaN        NaN
# ...

# %% [markdown]
# Column Rename

# %%
#df.query("Position == 'C'")

df=df.rename(columns={'College': 'College Name'})
df
# Out:
#                Number Position            Team   Age Height  Weight  \
# Name
# Avery Bradley     0.0       PG  Boston Celtics  25.0    6-2   180.0
# Jae Crowder      99.0       SF  Boston Celtics  25.0    6-6   235.0
# R.J. Hunter      28.0       SG  Boston Celtics  22.0    6-5   185.0
# Jordan Mickey    55.0       PF  Boston Celtics  21.0    6-8   235.0
# Kelly Olynyk     41.0        C  Boston Celtics  25.0    7-0   238.0
# ...               ...      ...             ...   ...    ...     ...
# Rodney Hood       5.0       SG       Utah Jazz  23.0    6-8   206.0
# Chris Johnson    23.0       SF       Utah Jazz  26.0    6-6   206.0
# Trey Lyles       41.0       PF       Utah Jazz  20.0   6-10   234.0
# Shelvin Mack      8.0       PG       Utah Jazz  26.0    6-3   203.0
# Jeff Withey      24.0        C       Utah Jazz  26.0    7-0   231.0
#
#                 College_Name     Salary
# Name
# Avery Bradley          Texas  7730337.0
# Jae Crowder        Marquette  6796117.0
# ...

# %%
col=[]
for data in df.columns:
    col.append(data.replace(' ', '_'))

col
# Out:
# ['Number',
#  'Position',
#  'Team',
#  'Age',
#  'Height',
#  'Weight',
#  'College_Name',
#  'Salary']

# %%
df.columns=[data.replace(' ', '_') for data in df.columns]

# %%
df.columns
# Out:
# Index(['Number', 'Position', 'Team', 'Age', 'Height', 'Weight', 'College_Name',
#        'Salary'],
#       dtype='object')

# %% [markdown]
# Q. Name Age and Team
#
# - Using Query methos, filter by age whose age is 28,21,13
# - Take on the name column and append Key word, Mr/Mrs

# %%
dfq = dfNba[['Name','Age','Team']]

# %%
dfq.query("Age in [28,21,13]")
# Out:
#                         Name   Age                    Team
# 6              Jordan Mickey  21.0          Boston Celtics
# 17           Wayne Ellington  28.0           Brooklyn Nets
# 18   Rondae Hollis-Jefferson  21.0           Brooklyn Nets
# 23               Brook Lopez  28.0           Brooklyn Nets
# 24          Chris McCullough  21.0           Brooklyn Nets
# 28              Donald Sloan  28.0           Brooklyn Nets
# 38               Robin Lopez  28.0         New York Knicks
# 42              Lance Thomas  28.0         New York Knicks
# 80             Stephen Curry  28.0   Golden State Warriors
# 88         Marreese Speights  28.0   Golden State Warriors
# 97            Wesley Johnson  28.0    Los Angeles Clippers
# 115            Julius Randle  21.0      Los Angeles Lakers
# 123           Chase Budinger  28.0            Phoenix Suns
# 125           Archie Goodwin  21.0            Phoenix Suns
# 142          Darren Collison  28.0        Sacramento Kings
# ...

# %%
df = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\NbaInfo.csv')


# df['Name'].apply( lambda x: 'Mr/Mrs {}'.format(x))

# %% [markdown]
# two words in names Mr ,
# 3 words in names Mrs

# %%
# def mrs(a):
    
#     l=len(str(a).split(' '))

#     if l==2:
#         return "Mr {}".format(a)
#     else:
#         return "Mrs {}".format(a)


df['Name'].apply( lambda x:"Mr {}".format(x) if len(str(x).split(' '))==2 else "Mrs {}".format(x))
# Out:
# 0      Mr Avery Bradley
# 1        Mr Jae Crowder
# 2       Mr John Holland
# 3        Mr R.J. Hunter
# 4      Mr Jonas Jerebko
#              ...
# 453     Mr Shelvin Mack
# 454        Mr Raul Neto
# 455     Mr Tibor Pleiss
# 456      Mr Jeff Withey
# 457             Mrs nan
# Name: Name, Length: 458, dtype: object

# %%
df['Name'].str.startswith('Mr')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 453    False
# 454    False
# 455    False
# 456    False
# 457      NaN
# Name: Name, Length: 458, dtype: object

# %% [markdown]
# Chicago City : Dataset

# %%
df = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\Chicago_city.csv')
df
# Out:
#                       Name            Position Title        Department  \
# 0          AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1        AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2           AARON,  KARINA            POLICE OFFICER            POLICE
# 3      AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4      ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
# ...                    ...                       ...               ...
# 32058   ZYGOWICZ,  PETER J            POLICE OFFICER            POLICE
# 32059    ZYMANTAS,  MARK E            POLICE OFFICER            POLICE
# 32060  ZYRKOWSKI,  CARLO E            POLICE OFFICER            POLICE
# 32061  ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST              DoIT
# 32062                  NaN                       NaN               NaN
#
#       Employee Annual Salary
# 0                  $90744.00
# 1                  $84450.00
# ...

# %%
df['Name']=df['Name'].str.lower()

# %%
df['Employee Annual Salary']=df['Employee Annual Salary'].str.replace('$','')
# Out:
# C:\Users\Miles\AppData\Local\Temp\ipykernel_3924\253300384.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Employee Annual Salary']=df['Employee Annual Salary'].str.replace('$','')

# %%
df['Employee Annual Salary']= df['Employee Annual Salary'].astype('float')

# %%
df['Position Title']= df['Position Title'].str.replace('-',' ').str.lower()

# %%
df.set_index('Position Title')
# Out:
#                                          Name        Department  \
# Position Title
# water rate taker              aaron,  elvia j       WATER MGMNT
# police officer              aaron,  jeffery m            POLICE
# police officer                 aaron,  karina            POLICE
# chief contract expediter  aaron,  kimberlei r  GENERAL SERVICES
# civil engineer iv         abad jr,  vicente m       WATER MGMNT
# ...                                       ...               ...
# police officer             zygowicz,  peter j            POLICE
# police officer              zymantas,  mark e            POLICE
# police officer            zyrkowski,  carlo e            POLICE
# chief data base analyst   zyskowski,  dariusz              DoIT
# NaN                                       NaN               NaN
#
#                           Employee Annual Salary
# Position Title
# water rate taker                         90744.0
# police officer                           84450.0
# ...

# %%
df['Position Title'].str.split(' ').str.get(0)
# Out:
# 0         water
# 1        police
# 2        police
# 3         chief
# 4         civil
#           ...
# 32058    police
# 32059    police
# 32060    police
# 32061     chief
# 32062       NaN
# Name: Position Title, Length: 32063, dtype: object

# %% [markdown]
# - Take department column, replace all the words MGMT with Management,
# - Find out those word with the keyword 'MENT' and count its occurance

# %%
df['Department'].str.replace('MGMNT','MANAGEMENT').str.lower().str.endswith('ment').value_counts()
# Out:
# False    29931
# True      2131
# Name: Department, dtype: int64

# %%
df.loc[df[df['College']== 'Georgia State'].index,'College'] = 'Tampa'

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# New Data

# %%
df = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\BigmacBurger_data2.csv', parse_dates=['Date'], index_col=['Date','Country'])
df
# Out:
#                       Price in US Dollars
# Date   Country
# Jan-16 Argentina                     2.39
#        Australia                     3.74
#        Brazil                        3.35
#        Britain                       4.22
#        Canada                        4.14
# ...                                   ...
# Jan-10 UAE                           2.99
#        Ukraine                       1.83
#        United States                 3.58
#        Uruguay                       3.32
#        Urgu                          3.32
#
# [653 rows x 1 columns]

# %% [markdown]
# Column Rename

# %%
df.rename(mapper={'oldName': 'newName'})
# Out:
#                       Price in US Dollars
# Date   Country
# Jan-16 Argentina                     2.39
#        Australia                     3.74
#        Brazil                        3.35
#        Britain                       4.22
#        Canada                        4.14
# ...                                   ...
# Jan-10 UAE                           2.99
#        Ukraine                       1.83
#        United States                 3.58
#        Uruguay                       3.32
#        Urgu                          3.32
#
# [653 rows x 1 columns]

# %%
# df.loc[('Jan-16','Argentina')]
df.loc[('Jan-16')].loc[('Argentina')]
# Out:
# Price in US Dollars    2.39
# Name: Argentina, dtype: float64

# %%
df.loc[('Jan-16')]['Argentina': 'Canada']
# Out:
#            Price in US Dollars
# Country
# Argentina                 2.39
# Australia                 3.74
# Brazil                    3.35
# Britain                   4.22
# Canada                    4.14

# %%
df.iloc[:5,:3]
# Out:
#                   Price in US Dollars
# Date   Country
# Jan-16 Argentina                 2.39
#        Australia                 3.74
#        Brazil                    3.35
#        Britain                   4.22
#        Canada                    4.14

# %%
df.index.get_level_values(1)
# Out:
# Index(['Argentina', 'Australia', 'Brazil', 'Britain', 'Canada', 'Chile',
#        'China', 'Colombia', 'Costa Rica', 'Czech Republic',
#        ...
#        'Sweden', 'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'UAE',
#        'Ukraine', 'United States', 'Uruguay', 'Urgu'],
#       dtype='object', name='Country', length=653)

# %% [markdown]
# Transpose

# %%
df.transpose()
# Out:
# Date                   Jan-16                                              \
# Country             Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars      2.39      3.74   3.35    4.22   4.14  2.94  2.68
#
# Date                                                    ... Jan-10  \
# Country             Colombia Costa Rica Czech Republic  ... Sweden
# Price in US Dollars     2.43       4.02           2.98  ...   5.51
#
# Date                                                                  \
# Country             Switzerland Taiwan Thailand Turkey   UAE Ukraine
# Price in US Dollars         6.3   2.36     2.11   3.83  2.99    1.83
#
# Date
# Country             United States Uruguay  Urgu
# Price in US Dollars          3.58    3.32  3.32
#
# [1 rows x 653 columns]

# %%
# df.transpose().loc[:,('Jan-16')].loc[:,'Argentina':'Canada']
df.transpose()['Jan-16'].loc[:,'Argentina':'Canada']
# Out:
# Country              Argentina  Australia  Brazil  Britain  Canada
# Price in US Dollars       2.39       3.74    3.35     4.22    4.14

# %%
df.transpose().loc['Price in US Dollars','Jan-16'][0:5]
# Out:
# Country
# Argentina    2.39
# Australia    3.74
# Brazil       3.35
# Britain      4.22
# Canada       4.14
# Name: Price in US Dollars, dtype: float64

# %% [markdown]
# Change Column Names

# %%
df.index.set_names(names=['Days','Values'])
# Out:
# MultiIndex([('Jan-16',      'Argentina'),
#             ('Jan-16',      'Australia'),
#             ('Jan-16',         'Brazil'),
#             ('Jan-16',        'Britain'),
#             ('Jan-16',         'Canada'),
#             ('Jan-16',          'Chile'),
#             ('Jan-16',          'China'),
#             ('Jan-16',       'Colombia'),
#             ('Jan-16',     'Costa Rica'),
#             ('Jan-16', 'Czech Republic'),
#             ...
#             ('Jan-10',         'Sweden'),
#             ('Jan-10',    'Switzerland'),
#             ('Jan-10',         'Taiwan'),
#             ('Jan-10',       'Thailand'),
#             ('Jan-10',         'Turkey'),
#             ('Jan-10',            'UAE'),
#             ('Jan-10',        'Ukraine'),
#             ('Jan-10',  'United States'),
#             ('Jan-10',        'Uruguay'),
#             ('Jan-10',           'Urgu')],
#            names=['Days', 'Values'], length=653)

# %%
df.index
# Out:
# MultiIndex([('Jan-16',      'Argentina'),
#             ('Jan-16',      'Australia'),
#             ('Jan-16',         'Brazil'),
#             ('Jan-16',        'Britain'),
#             ('Jan-16',         'Canada'),
#             ('Jan-16',          'Chile'),
#             ('Jan-16',          'China'),
#             ('Jan-16',       'Colombia'),
#             ('Jan-16',     'Costa Rica'),
#             ('Jan-16', 'Czech Republic'),
#             ...
#             ('Jan-10',         'Sweden'),
#             ('Jan-10',    'Switzerland'),
#             ('Jan-10',         'Taiwan'),
#             ('Jan-10',       'Thailand'),
#             ('Jan-10',         'Turkey'),
#             ('Jan-10',            'UAE'),
#             ('Jan-10',        'Ukraine'),
#             ('Jan-10',  'United States'),
#             ('Jan-10',        'Uruguay'),
#             ('Jan-10',           'Urgu')],
#            names=['Date', 'Country'], length=653)

# %% [markdown]
# Date as Index

# %%
df = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\BigmacBurger_data2.csv', parse_dates=['Date'], index_col=['Date'])
df
# Out:
#               Country  Price in US Dollars
# Date
# Jan-16      Argentina                 2.39
# Jan-16      Australia                 3.74
# Jan-16         Brazil                 3.35
# Jan-16        Britain                 4.22
# Jan-16         Canada                 4.14
# ...               ...                  ...
# Jan-10            UAE                 2.99
# Jan-10        Ukraine                 1.83
# Jan-10  United States                 3.58
# Jan-10        Uruguay                 3.32
# Jan-10           Urgu                 3.32
#
# [653 rows x 2 columns]

# %% [markdown]
# Stack Methos

# %%
df.stack()

# df.unstack()
df.head()
# Out:
#           Country  Price in US Dollars
# Date
# Jan-16  Argentina                 2.39
# Jan-16  Australia                 3.74
# Jan-16     Brazil                 3.35
# Jan-16    Britain                 4.22
# Jan-16     Canada                 4.14

# %% [markdown]
# Pivot

# %%
df = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\BigmacBurger_data2.csv', parse_dates=['Date'])

df.pivot(index='Date',columns=['Country'],values='Price in US Dollars')
# Out:
# Country  Argentina  Australia  Austria  Belgium  Brazil  Britain  Canada  \
# Date
# Jan-10        1.84       3.98      NaN      NaN    4.76     3.67    3.97
# Jan-12        4.64       4.94     3.92     4.69    5.68     3.82    4.63
# Jan-13        3.82       4.90     4.60     5.16    5.64     4.25    5.39
# Jan-14        3.03       4.47     4.60     5.36    5.25     4.63    5.01
# Jan-15        3.25       4.32     3.93     4.29    5.21     4.37    4.64
# Jan-16        2.39       3.74     3.76     4.25    3.35     4.22    4.14
# Jul-10        3.56       3.84      NaN      NaN    4.91     3.48    4.00
# Jul-11        4.84       4.94     4.43     5.38    6.16     3.89    5.00
# Jul-12        4.16       4.68     3.87     4.61    4.94     4.16    5.02
# Jul-13        3.88       4.62     4.36     4.76    5.28     4.02    5.26
# Jul-14        2.57       4.81     4.56     4.98    5.86     4.93    5.25
# Jul-15        3.07       3.92     3.71     4.05    4.28     4.51    4.54
#
# ...

# %% [markdown]
# Q.
# - Name as Index
# - Team as Pivot Table (COlumn)
# - Salary as Value

# %%
df = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\EmployeesInfo.csv')

# df.fillna('New', inplace=True)
df=df[~df.duplicated(subset='First Name')]

# %%
# df=df.pivot(index='Team', columns='First Name', values='Salary')

df.head()
# Out:
# First Name            NaN  Aaron     Adam  Alan   Albert  Alice   Amanda  \
# Team
# NaN                   NaN    NaN      NaN   NaN      NaN    NaN      NaN
# Business Development  NaN    NaN      NaN   NaN      NaN    NaN      NaN
# Client Services       NaN    NaN      NaN   NaN      NaN    NaN      NaN
# Distribution          NaN    NaN  95327.0   NaN      NaN    NaN  80803.0
# Engineering           NaN    NaN      NaN   NaN  67827.0    NaN      NaN
#
# First Name                 Amy    Andrea   Andrew  ...  Timothy  Tina  Todd  \
# Team                                               ...
# NaN                        NaN       NaN      NaN  ...      NaN   NaN   NaN
# Business Development       NaN  120204.0      NaN  ...      NaN   NaN   NaN
# Client Services            NaN       NaN  43414.0  ...      NaN   NaN   NaN
# Distribution               NaN       NaN      NaN  ...      NaN   NaN   NaN
# Engineering           122897.0       NaN      NaN  ...      NaN   NaN   NaN
#
# ...

# %%
df.transpose()
# Out:
# Team        NaN  Business Development  Client Services  Distribution  \
# First Name
# NaN         NaN                   NaN              NaN           NaN
# Aaron       NaN                   NaN              NaN           NaN
# Adam        NaN                   NaN              NaN       95327.0
# Alan        NaN                   NaN              NaN           NaN
# Albert      NaN                   NaN              NaN           NaN
# ...         ...                   ...              ...           ...
# Walter      NaN                   NaN              NaN           NaN
# Wanda       NaN                   NaN              NaN           NaN
# Wayne       NaN                   NaN              NaN      102652.0
# William     NaN                   NaN              NaN           NaN
# Willie      NaN                   NaN              NaN           NaN
#
# Team        Engineering   Finance  Human Resources    Legal  Marketing  \
# First Name
# ...

# %% [markdown]
# Total amount spend by Female user

# %%
df = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\userfoods.csv')
df.head()
# Out:
#   First Name  Gender          City Frequency       Item  Spend
# 0      Wanda  Female      Stamford    Weekly     Burger  15.66
# 1       Eric    Male      Stamford     Daily    Chalupa  10.56
# 2    Charles    Male      New York     Never      Sushi  42.14
# 3       Anna  Female  Philadelphia      Once  Ice Cream  11.01
# 4    Deborah  Female  Philadelphia     Daily    Chalupa  23.49

# %%
df.pivot_table(index='Gender',values='Spend',aggfunc=sum)
# Out:
#            Spend
# Gender
# Female  25963.33
# Male    24106.04

# %%
df.pivot_table(index='Gender',columns=['Item'],values=['Spend'],aggfunc=sum)
# Out:
#           Spend
# Item     Burger  Burrito  Chalupa    Donut Ice Cream    Sushi
# Gender
# Female  4094.30  4257.82  4152.26  4743.00   4032.87  4683.08
# Male    3671.43  4012.62  3492.26  4015.76   4854.12  4059.85

# %%
pdf=df.pivot_table(index=['Item'],columns='City',values=['Spend'],aggfunc=sum)
pdf
# Out:
#              Spend
# City      New York Philadelphia Stamford
# Item
# Burger     2533.13      2577.42  2655.18
# Burrito    2378.35      2771.69  3120.40
# Chalupa    2104.35      2787.56  2752.61
# Donut      2792.05      2888.62  3078.09
# Ice Cream  3125.25      3670.49  2091.25
# Sushi      2876.44      3138.76  2727.73

# %% [markdown]
# Q. Covert a Pivot Table into the DF *melt* method

# %%
# pandas.melt(frame, id_vars=None, value_vars=None, var_name=None, value_name='value', col_level=None, sort=False)

pd.melt(pdf)
# Out:
#      None          City    value
# 0   Spend      New York  2533.13
# 1   Spend      New York  2378.35
# 2   Spend      New York  2104.35
# 3   Spend      New York  2792.05
# 4   Spend      New York  3125.25
# 5   Spend      New York  2876.44
# 6   Spend  Philadelphia  2577.42
# 7   Spend  Philadelphia  2771.69
# 8   Spend  Philadelphia  2787.56
# 9   Spend  Philadelphia  2888.62
# 10  Spend  Philadelphia  3670.49
# 11  Spend  Philadelphia  3138.76
# 12  Spend      Stamford  2655.18
# 13  Spend      Stamford  3120.40
# 14  Spend      Stamford  2752.61
# 15  Spend      Stamford  3078.09
# 16  Spend      Stamford  2091.25
# 17  Spend      Stamford  2727.73

# %% [markdown]
# Group BY

# %%
df = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\fortune_data.csv')
df2 = df
df.head()
# Out:
#    Rank             Company       Sector  \
# 0     1             Walmart    Retailing
# 1     2         Exxon Mobil       Energy
# 2     3               Apple   Technology
# 3     4  Berkshire Hathaway   Financials
# 4     5            McKesson  Health Care
#
#                                    Industry           Location  Revenue  \
# 0                     General Merchandisers    Bentonville, AR   482130
# 1                        Petroleum Refining         Irving, TX   246204
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 4                  Wholesalers: Health Care  San Francisco, CA   181241
#
#    Profits  Employees
# 0    14694    2300000
# 1    16150      75600
# 2    53394     110000
# 3    24083     331000
# 4     1476      70400

# %%
df['Sector'].nunique()
# Out:
# 21

# %%
sectorGroups=df.groupby(by='Sector')

# %%
sectorGroups.groups
# Out:
# {'Aerospace & Defense': [23, 44, 59, 87, 117, 119, 208, 244, 281, 377, 388, 489, 559, 604, 784, 787, 835, 902, 957, 986], 'Apparel': [90, 230, 339, 353, 447, 546, 574, 596, 682, 694, 725, 793, 876, 881, 916], 'Business Services': [143, 185, 198, 203, 220, 247, 248, 293, 306, 311, 354, 391, 403, 439, 466, 467, 480, 484, 491, 502, 544, 625, 634, 651, 676, 693, 713, 728, 733, 734, 736, 743, 766, 775, 776, 782, 790, 791, 795, 800, 802, 815, 818, 819, 868, 869, 885, 938, 950, 951, 992], 'Chemicals': [55, 100, 181, 188, 205, 252, 261, 276, 287, 295, 315, 537, 548, 554, 565, 579, 612, 623, 653, 667, 716, 719, 723, 757, 760, 828, 864, 897, 933, 948], 'Energy': [1, 13, 29, 31, 41, 64, 89, 94, 97, 103, 114, 116, 120, 161, 162, 164, 165, 174, 177, 187, 189, 191, 192, 197, 213, 215, 216, 222, 224, 228, 242, 245, 246, 256, 271, 273, 278, 288, 318, 321, 323, 342, 347, 348, 349, 362, 363, 383, 386, 387, 393, 401, 402, 409, 424, 436, 437, 444, 457, 474, 482, 492, 506, 521, 540, 547, 555, 557, 568, 5
# ...

# %%
sectorGroups.get_group('Aerospace & Defense')
# Out:
#      Rank                        Company               Sector  \
# 23     24                         Boeing  Aerospace & Defense
# 44     45            United Technologies  Aerospace & Defense
# 59     60                Lockheed Martin  Aerospace & Defense
# 87     88               General Dynamics  Aerospace & Defense
# 117   118               Northrop Grumman  Aerospace & Defense
# 119   120                       Raytheon  Aerospace & Defense
# 208   209                        Textron  Aerospace & Defense
# 244   245             L-3 Communications  Aerospace & Defense
# 281   282            Precision Castparts  Aerospace & Defense
# 377   378  Huntington Ingalls Industries  Aerospace & Defense
# 388   389    Spirit AeroSystems Holdings  Aerospace & Defense
# 489   490               Rockwell Collins  Aerospace & Defense
# 559   560                    Orbital ATK  Aerospace & Defense
# 604   605                  Triumph Group  Aerospace & Defense
# ...

# %% [markdown]
# First Value from each Category

# %%
sectorGroups.first()
# Out:
#                               Rank                 Company  \
# Sector
# Aerospace & Defense             24                  Boeing
# Apparel                         91                    Nike
# Business Services              144           ManpowerGroup
# Chemicals                       56            Dow Chemical
# Energy                           2             Exxon Mobil
# Engineering & Construction     155                   Fluor
# Financials                       4      Berkshire Hathaway
# Food and Drug Stores             7              CVS Health
# Food, Beverages & Tobacco       41  Archer Daniels Midland
# Health Care                      5                McKesson
# Hotels, Resturants & Leisure   109              McDonald’s
# Household Products              34        Procter & Gamble
# Industrials                     11        General Electric
# Materials                      126                   Alcoa
# Media                           53                  Disney
# ...

# %% [markdown]
# Last Value from each Category

# %%
sectorGroups.last()
# Out:
#                               Rank                            Company  \
# Sector
# Aerospace & Defense            987              Delta Tucker Holdings
# Apparel                        917                              Guess
# Business Services              993              DeVry Education Group
# Chemicals                      949                        H.B. Fuller
# Energy                         997          Portland General Electric
# Engineering & Construction     994                       MDC Holdings
# Financials                     996         New York Community Bancorp
# Food and Drug Stores           928                             Fred’s
# Food, Beverages & Tobacco      954         Alliance One International
# Health Care                    978                 Providence Service
# Hotels, Resturants & Leisure   999                            Wendy’s
# Household Products             992                             Revlon
# ...

# %% [markdown]
# - Max profit for Energy Sector

# %%
sectorGroups.get_group('Energy')['Profits'].agg('max')
# Out:
# 16150

# %% [markdown]
# - Avg employees for Advertising,marketing

# %%
df[df['Industry'] == 'Advertising, marketing']['Employees'].mean()
# Out:
# 62050.0

# %%
df.groupby(by='Industry').get_group('Advertising, marketing')['Employees'].agg('mean')
# Out:
# 62050.0

# %%
sectorGroups['Profits'].max().get('Energy')
# Out:
# 16150

# %%
sectorNew = df.groupby(['Sector','Industry'])

# %% [markdown]
# To see the Group By Data

# %%
sectorNew.groups
# Out:
# {('Aerospace & Defense', 'Aerospace and Defense'): [23, 44, 59, 87, 117, 119, 208, 244, 281, 377, 388, 489, 559, 604, 784, 787, 835, 902, 957, 986], ('Apparel', 'Apparel'): [90, 230, 339, 353, 447, 546, 574, 596, 682, 694, 725, 793, 876, 881, 916], ('Business Services', 'Advertising, marketing'): [185, 354], ('Business Services', 'Diversified Outsourcing Services'): [198, 247, 484, 544, 625, 634, 713, 728, 743, 782, 802, 815, 818, 868], ('Business Services', 'Education'): [736, 819, 992], ('Business Services', 'Financial Data Services'): [203, 248, 293, 306, 391, 403, 467, 480, 491, 651, 693, 766, 775, 776, 791, 795, 800, 885, 951], ('Business Services', 'Miscellaneous'): [439, 733, 869], ('Business Services', 'Temporary Help'): [143, 466, 502, 790, 950], ('Business Services', 'Waste Management'): [220, 311, 676, 734, 938], ('Chemicals', 'Chemicals'): [55, 100, 181, 188, 205, 252, 261, 276, 287, 295, 315, 537, 548, 554, 565, 579, 612, 623, 653, 667, 716, 719, 723, 757, 760, 828, 864,
# ...

# %%
sectorNew.get_group(('Energy', 'Petroleum Refining'))
# Out:
#      Rank                              Company  Sector            Industry  \
# 1       2                          Exxon Mobil  Energy  Petroleum Refining
# 13     14                              Chevron  Energy  Petroleum Refining
# 29     30                          Phillips 66  Energy  Petroleum Refining
# 31     32                        Valero Energy  Energy  Petroleum Refining
# 41     42                   Marathon Petroleum  Energy  Petroleum Refining
# 97     98                               Tesoro  Energy  Petroleum Refining
# 213   214                        HollyFrontier  Energy  Petroleum Refining
# 216   217                           PBF Energy  Energy  Petroleum Refining
# 288   289                     Western Refining  Energy  Petroleum Refining
# 393   394                                 Hess  Energy  Petroleum Refining
# 444   445                    Delek US Holdings  Energy  Petroleum Refining
# ...

# %%
sectorNew.agg(['min', 'max', 'mean'])
# Out:
# C:\Users\Miles\AppData\Local\Temp\ipykernel_3924\765127957.py:1: FutureWarning: ['Company', 'Location'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   sectorNew.agg(['min', 'max', 'mean'])
#                                                                   Rank       \
#                                                                    min  max
# Sector              Industry
# Aerospace & Defense Aerospace and Defense                           24  987
# Apparel             Apparel                                         91  917
# Business Services   Advertising, marketing                         186  355
#                     Diversified Outsourcing Services               199  869
#                     Education                                      737  993
# ...                                                                ...  ...
# ...

# %%
sectorNew.agg({'Revenue':'sum', 'Profits':'mean'})
# Out:
#                                                                    Revenue  \
# Sector              Industry
# Aerospace & Defense Aerospace and Defense                           357940
# Apparel             Apparel                                          95968
# Business Services   Advertising, marketing                           22748
#                     Diversified Outsourcing Services                 64829
#                     Education                                         7485
# ...                                                                    ...
# Transportation      Trucking, Truck Leasing                          35950
# Wholesalers         Miscellaneous                                     8982
#                     Wholesalers: Diversified                        176138
#                     Wholesalers: Electronics and Office Equipment   147906
#                     Wholesalers: Food and Grocery                   111774
#
# ...

# %% [markdown]
# DataFrame Concat

# %%
pd.concat([df,df2], ignore_index=True)
# Out:
#       Rank                     Company                        Sector  \
# 0        1                     Walmart                     Retailing
# 1        2                 Exxon Mobil                        Energy
# 2        3                       Apple                    Technology
# 3        4          Berkshire Hathaway                    Financials
# 4        5                    McKesson                   Health Care
# ...    ...                         ...                           ...
# 1995   996  New York Community Bancorp                    Financials
# 1996   997   Portland General Electric                        Energy
# 1997   997   Portland General Electric                        Energy
# 1998   999                     Wendy’s  Hotels, Resturants & Leisure
# 1999  1000           Briggs & Stratton                   Industrials
#
#                                       Industry           Location  Revenue  \
# ...

# %%
df.merge(df2, how='inner', on='Company')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 df.merge(df2, how='inner', on='Company')
#
# NameError: name 'df2' is not defined

# %%
df = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\movielens.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[159], line 1
# ----> 1 df = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\movielens.csv')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %% [markdown]
# - create a df, ratings & movies
# - change DataType
# - perfom inner join on both to extract - userId, MovieId and MovieName

# %%
dfMovies = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\movies.csv')
dfRatings = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\ratings.csv')
dfLinks = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\links.csv')
dfTags = pd.read_csv(r'C:\Users\Miles\Documents\Futurense\Python\Datasets\tags.csv')

# %%
dfMovies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   title    9742 non-null   object
#  2   genres   9742 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 228.5+ KB

# %%
dfRatings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
dfRatings.merge(dfMovies, how='inner', on='movieId')[['userId','movieId','title']]
# Out:
#         userId  movieId                             title
# 0            1        1                  Toy Story (1995)
# 1            5        1                  Toy Story (1995)
# 2            7        1                  Toy Story (1995)
# 3           15        1                  Toy Story (1995)
# 4           17        1                  Toy Story (1995)
# ...        ...      ...                               ...
# 100831     610   160341                  Bloodmoon (1997)
# 100832     610   160527  Sympathy for the Underdog (1971)
# 100833     610   160836                     Hazard (2005)
# 100834     610   163937                Blair Witch (2016)
# 100835     610   163981                         31 (2016)
#
# [100836 rows x 3 columns]

# %%
dfRatings=dfRatings.rename(columns={'movieId':'movie_id'})
pd.merge()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[453], line 2
#       1 dfRatings=dfRatings.rename(columns={'movieId':'movie_id'})
# ----> 2 pd.merge()
#
# TypeError: merge() missing 2 required positional arguments: 'left' and 'right'

# %%
dfRatings.merge(dfMovies,left_on='movie_id',right_on='movieId',how='inner')[['userId','movieId','title']]
# Out:
#         userId  movieId                             title
# 0            1        1                  Toy Story (1995)
# 1            5        1                  Toy Story (1995)
# 2            7        1                  Toy Story (1995)
# 3           15        1                  Toy Story (1995)
# 4           17        1                  Toy Story (1995)
# ...        ...      ...                               ...
# 100831     610   160341                  Bloodmoon (1997)
# 100832     610   160527  Sympathy for the Underdog (1971)
# 100833     610   160836                     Hazard (2005)
# 100834     610   163937                Blair Witch (2016)
# 100835     610   163981                         31 (2016)
#
# [100836 rows x 3 columns]

# %%
dfRatings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movie_id   100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
dfRatings.merge(dfTags,left_on=['userId','movie_id'],right_on=['userId','movieId'],how='inner')[['userId','movie_id','tag']]
# Out:
#       userId  movie_id               tag
# 0          2     60756             funny
# 1          2     60756   Highly quotable
# 2          2     60756      will ferrell
# 3          2     89774      Boxing story
# 4          2     89774               MMA
# ...      ...       ...               ...
# 3471     606      6107      World War II
# 3472     606      7382         for katie
# 3473     610      3265            gun fu
# 3474     610      3265  heroic bloodshed
# 3475     610    168248  Heroic Bloodshed
#
# [3476 rows x 3 columns]

# %%
dfRatings.merge(dfTags,left_on=['userId','movie_id'],right_on=['userId','movieId'],how='inner').merge(dfMovies,left_on='movie_id',right_on='movieId', how='inner')[['userId','movie_id','rating','tag','title']]
# Out:
#       userId  movie_id  rating               tag  \
# 0          2     60756     5.0             funny
# 1          2     60756     5.0   Highly quotable
# 2          2     60756     5.0      will ferrell
# 3         62     60756     3.5            comedy
# 4         62     60756     3.5             funny
# ...      ...       ...     ...               ...
# 3471     606      1948     3.5           British
# 3472     606      5694     3.0              70mm
# 3473     606      6107     4.0      World War II
# 3474     610      3265     5.0            gun fu
# 3475     610      3265     5.0  heroic bloodshed
#
#                                                   title
# 0                                  Step Brothers (2008)
# 1                                  Step Brothers (2008)
# 2                                  Step Brothers (2008)
# 3                                  Step Brothers (2008)
# 4                                  Step Brothers (2008)
# ...

# %%
dfRatings.merge(dfTags,left_on=['userId','movie_id'],right_on=['userId','movieId'],how='outer',suffixes=['1','2'])[['userId','movie_id','rating','tag']]
# Out:
#         userId  movie_id  rating          tag
# 0            1       1.0     4.0          NaN
# 1            1       3.0     4.0          NaN
# 2            1       6.0     4.0          NaN
# 3            1      47.0     5.0          NaN
# 4            1      50.0     5.0          NaN
# ...        ...       ...     ...          ...
# 102879     573       NaN     NaN     not seen
# 102880     573       NaN     NaN          bad
# 102881     573       NaN     NaN  Ben Affleck
# 102882     600       NaN     NaN       gothic
# 102883     606       NaN     NaN      austere
#
# [102884 rows x 4 columns]

# %% [markdown]
# Time Series

# %%
import datetime as dt

from pandas_datareader import data

# %%
time1=dt.datetime(2011,9,21)

# %%
str(dt.datetime(2011,9,21))
# Out:
# '2011-09-21 00:00:00'

# %%
time1.year
# Out:
# 2011

# %%
pd.Timestamp('2012-Oct-2')
# Out:
# Timestamp('2012-10-02 00:00:00')

# %%
pd.Timestamp('2-3-2012')
# Out:
# Timestamp('2012-02-03 00:00:00')

# %%
pd.date_range('2023-02-1','2023-02-28', freq='2D')
# Out:
# DatetimeIndex(['2023-02-01', '2023-02-03', '2023-02-05', '2023-02-07',
#                '2023-02-09', '2023-02-11', '2023-02-13', '2023-02-15',
#                '2023-02-17', '2023-02-19', '2023-02-21', '2023-02-23',
#                '2023-02-25', '2023-02-27'],
#               dtype='datetime64[ns]', freq='2D')

# %%
pd.date_range('2023-02-1','2023-02-28', freq='M')
# Out:
# DatetimeIndex(['2023-02-28'], dtype='datetime64[ns]', freq='M')

# %%
pd.date_range('2023-02-1','2023-02-28', freq='B')
# Out:
# DatetimeIndex(['2023-02-01', '2023-02-02', '2023-02-03', '2023-02-06',
#                '2023-02-07', '2023-02-08', '2023-02-09', '2023-02-10',
#                '2023-02-13', '2023-02-14', '2023-02-15', '2023-02-16',
#                '2023-02-17', '2023-02-20', '2023-02-21', '2023-02-22',
#                '2023-02-23', '2023-02-24', '2023-02-27', '2023-02-28'],
#               dtype='datetime64[ns]', freq='B')

# %%
dateSeries = pd.Series(pd.date_range('2023-01-1','2023-03-26', freq='15D'))

# %%
dateSeries.dt.day_of_week
# Out:
# 0    6
# 1    0
# 2    1
# 3    2
# 4    3
# 5    4
# dtype: int64

# %%
stocks = data.DataReader(name='MSFT',data_source='stooq',start='2022-01-01', end='2023-01-01')

# %%
stocks.head()
# Out:
#               Open    High       Low   Close      Volume
# Date
# 2022-12-30  238.21  239.96  236.6600  239.82  21938472.0
# 2022-12-29  235.65  241.92  235.6500  241.01  19770693.0
# 2022-12-28  236.89  239.72  234.1700  234.53  17457104.0
# 2022-12-27  238.70  238.93  235.8300  236.96  16688648.0
# 2022-12-23  236.11  238.87  233.9428  238.73  21206982.0

# %% [markdown]
# Q.
# - Find the Total amount of Volume of Share that has been trade from Monday to Wednesday
# - Get the Highest Value of the stock which has been placed in each year
# - Find the minimum closing values of each quarter in the year 2022

# %%
stocks[stocks['Date'].dt.day_of_week.isin([0, 1, 2])]['Volume'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
stocksDate=stocks.groupby(by='Date')

# %%
stocks['quarter']=stocks['Date'].dt.quarter

# %%
stocksQuarter=stocks.groupby(by='quarter')

# %% [markdown]
# 3rd Question

# %%
stocksQuarter.agg('min')
# Out:
#               Date     Open     High      Low    Close        Volume
# quarter
# 1       2022-01-03  270.539  281.906  268.047  273.854  2.273090e+07
# 2       2022-04-01  242.659  244.530  240.321  241.068  1.745828e+07
# 3       2022-07-01  236.145  239.276  232.076  232.245  1.663014e+07
# 4       2022-10-03  216.939  219.791  212.831  213.648  9.200772e+06

# %% [markdown]
# Time Delta

# %%
# Create two dates
start_date = pd.to_datetime("2022-01-01")
end_date = pd.to_datetime("2022-01-15")

# Calculate the time delta between the two dates
time_delta = end_date - start_date
time_delta
# Result:
# Timedelta('14 days 00:00:00')
# Out:
# Timedelta('14 days 00:00:00')

# %% [markdown]
# Date Offset

# %%
from pandas.tseries.offsets import DateOffset
DateOffset()

# %%
ts = pd.Timestamp('2017-01-01 09:10:11')

ts + DateOffset(months=3)

# Timestamp('2017-04-01 09:10:11')
# Out:
# Timestamp('2017-04-01 09:10:11')

# %%
stocks['Date']
# Out:
# 0     2022-12-30
# 1     2022-12-29
# 2     2022-12-28
# 3     2022-12-27
# 4     2022-12-23
#          ...
# 246   2022-01-07
# 247   2022-01-06
# 248   2022-01-05
# 249   2022-01-04
# 250   2022-01-03
# Name: Date, Length: 251, dtype: datetime64[ns]

# %%
stocks['Date'] + DateOffset(days=2)

stocks['Date'] + DateOffset(month=2)
# Out:
# C:\Users\Miles\AppData\Local\Temp\ipykernel_28268\896185638.py:3: PerformanceWarning: Non-vectorized DateOffset being applied to Series or DatetimeIndex.
#   stocks['Date'] + DateOffset(month=2)
# 0     2022-02-28
# 1     2022-02-28
# 2     2022-02-28
# 3     2022-02-27
# 4     2022-02-23
#          ...
# 246   2022-02-07
# 247   2022-02-06
# 248   2022-02-05
# 249   2022-02-04
# 250   2022-02-03
# Name: Date, Length: 251, dtype: datetime64[ns]

# %%
stocks['Date'].get(5)
# Out:
# Timestamp('2022-12-22 00:00:00')

# %%
stocks.iloc[:3]
# Out:
#               Open    High     Low   Close      Volume
# Date
# 2022-12-30  238.21  239.96  236.66  239.82  21938472.0
# 2022-12-29  235.65  241.92  235.65  241.01  19770693.0
# 2022-12-28  236.89  239.72  234.17  234.53  17457104.0

# %%
stocks.index[0:3]
# Out:
# DatetimeIndex(['2022-12-30', '2022-12-29', '2022-12-28'], dtype='datetime64[ns]', name='Date', freq=None)
