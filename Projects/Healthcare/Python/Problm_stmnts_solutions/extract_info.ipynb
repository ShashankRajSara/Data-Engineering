# %% [markdown]
# ## Extract Information from the housing data along with the census data

# %%
# Siddhu, from Healthcare Department, has reported that the household data that they have (Data/housing.csv), 
# requires some processing in the context of the census data so that more information can be extracted from it.
# Process the housing data and census data to gain some insight.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# new_names = {"PONDICHERRY" : "Puducherry",
# "ORISSA" : "Odisha",
# "NCT OF DELHI" : "Delhi"}
new_names = {'PONDICHERRY': 'PUDUCHERRY', 'ORISSA': 'ODISHA', 'NCT OF DELHI': 'DELHI'}

# %% [markdown]
# ### Problem Statement 7: (Process the relevant data)

# %%
# In the given data The total number of households, Total Number of Livable, Total Number of Dilapidated, Latrine_premise, etc. 
# seem to be in percentage terms and not in absolute terms.

# The total number of households in a district can be found in the census data. 
# Take the information from the census data and find the absolute values for the Total Number of Dilapidated, 
# and Latrine_premise for both rural and urban areas of each district.

# Calculate the data and rename the column names and save it in a CSV file named “housing.csv” in the “Clean_Data” folder, 
# such that it has the following column names:

# %%
cols_h =  ["District Name",
"Rural/Urban",
"Total Number of households",
"Total Number of Livable",
"Total Number of Dilapidated",
"Latrine_premise",
"State Name"
]

new_cols =["District",
"Households_Rural",
"Households_Rural_Livable",
"Households_Rural_Dilapidated",
"Households_Rural_Toilet_Premise",
"Households_Urban",
"Households_Urban_Livable",
"Households_Urban_Dilapidated",
"Households_Urban_Toilet_Premise"]

# %%
df_housing = pd.read_csv('../data/housing.csv',usecols=cols_h)
df_housing.head()
# Out:
#         State Name District Name Rural/Urban  Total Number of households  \
# 0  JAMMU & KASHMIR       Kupwara       Rural                         100
# 1  JAMMU & KASHMIR       Kupwara       Total                         100
# 2  JAMMU & KASHMIR       Kupwara       Urban                         100
# 3  JAMMU & KASHMIR        Badgam       Rural                         100
# 4  JAMMU & KASHMIR        Badgam       Total                         100
#
#    Total Number of Livable  Total Number of Dilapidated  Latrine_premise
# 0                     58.1                          8.3             48.9
# 1                     57.3                          7.9             50.9
# 2                     49.5                          4.8             70.2
# 3                     46.3                          3.9             83.3
# 4                     44.7                          3.8             84.3

# %%
df_housing['State Name'] = df_housing['State Name'].apply(lambda x: x.replace('&', 'AND'))
df_housing.head()
# Out:
#           State Name District Name Rural/Urban  Total Number of households  \
# 0  JAMMU AND KASHMIR       Kupwara       Rural                         100
# 1  JAMMU AND KASHMIR       Kupwara       Total                         100
# 2  JAMMU AND KASHMIR       Kupwara       Urban                         100
# 3  JAMMU AND KASHMIR        Badgam       Rural                         100
# 4  JAMMU AND KASHMIR        Badgam       Total                         100
#
#    Total Number of Livable  Total Number of Dilapidated  Latrine_premise
# 0                     58.1                          8.3             48.9
# 1                     57.3                          7.9             50.9
# 2                     49.5                          4.8             70.2
# 3                     46.3                          3.9             83.3
# 4                     44.7                          3.8             84.3

# %%
# updating the state names in housing data
df_housing['State Name'] = df_housing.apply(lambda x: new_names[x['State Name']] if x['State Name'].upper() in new_names.keys()
                                    else x['State Name'], axis=1)

# %%
df_housing.iloc[[200,300,400,500],:]
# Out:
#         State Name District Name Rural/Urban  Total Number of households  \
# 200    UTTARAKHAND       Hardwar       Total                         100
# 300      RAJASTHAN         Churu       Total                         100
# 400  UTTAR PRADESH     Moradabad       Urban                         100
# 500  UTTAR PRADESH        Mahoba       Rural                         100
#
#      Total Number of Livable  Total Number of Dilapidated  Latrine_premise
# 200                     39.4                          4.1             66.6
# 300                     36.8                          4.9             57.8
# 400                     46.2                          3.2             93.6
# 500                     50.7                          1.7             17.8

# %%
# reading census data
df_census = pd.read_csv('../Data/census_2011.csv')
df_census.head()
# Out:
#    District code         State name District name  Population      Male  \
# 0              1  JAMMU AND KASHMIR       Kupwara    870354.0  474190.0
# 1              2  JAMMU AND KASHMIR        Badgam    753745.0       NaN
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)    133487.0   78971.0
# 3              4  JAMMU AND KASHMIR        Kargil    140802.0       NaN
# 4              5  JAMMU AND KASHMIR         Punch         NaN  251899.0
#
#      Female  Literate  Male_Literate  Female_Literate      SC  ...  \
# 0  396164.0  439654.0       282823.0         156831.0  1048.0  ...
# 1  355704.0  335649.0       207741.0         127908.0     NaN  ...
# 2   54516.0   93770.0        62834.0          30936.0   488.0  ...
# 3   63017.0       NaN        56301.0          29935.0    18.0  ...
# 4  224936.0  261724.0       163333.0          98391.0   556.0  ...
#
#    Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 0                          94.0                         588.0
# 1                         126.0                         562.0
# 2                          46.0                         122.0
# 3                          27.0                         114.0
# 4                          78.0                         346.0
#
#    Power_Parity_Rs_150000_240000  Power_Parity_Rs_240000_330000  \
# 0                           71.0                          101.0
# 1                           72.0                           89.0
# 2                           15.0                           22.0
# 3                           12.0                           18.0
# 4                           35.0                           50.0
#
#    Power_Parity_Rs_150000_330000  Power_Parity_Rs_330000_425000  \
# 0                          172.0                           74.0
# 1                          161.0                           96.0
# 2                            NaN                           20.0
# 3                           30.0                           19.0
# 4                           85.0                           59.0
#
#    Power_Parity_Rs_425000_545000  Power_Parity_Rs_330000_545000  \
# 0                           10.0                           84.0
# 1                           28.0                          124.0
# 2                            NaN                            NaN
# 3                            3.0                           22.0
# 4                            8.0                           67.0
#
#    Power_Parity_Above_Rs_545000  Total_Power_Parity
# 0                          15.0              1119.0
# 1                          18.0              1066.0
# 2                          17.0               242.0
# 3                           7.0               214.0
# 4                          12.0               629.0
#
# [5 rows x 118 columns]

# %%
# for i in df_census.columns:
#     if 'ur' in i.lower():
#         print(i)

# %%
df_dist_pop = df_census[['District name','Population','Rural_Households','Urban_Households','State name']]
df_dist_pop.head()
# Out:
#   District name  Population  Rural_Households  Urban_Households  \
# 0       Kupwara    870354.0          158438.0               NaN
# 1        Badgam    753745.0          160649.0           27190.0
# 2   Leh(Ladakh)    133487.0           36920.0           17474.0
# 3        Kargil    140802.0           40370.0            7774.0
# 4         Punch         NaN          132139.0           15269.0
#
#           State name
# 0  JAMMU AND KASHMIR
# 1  JAMMU AND KASHMIR
# 2  JAMMU AND KASHMIR
# 3  JAMMU AND KASHMIR
# 4  JAMMU AND KASHMIR

# %%
# updating the state names in df derived from census data
df_dist_pop['State name'] =  df_dist_pop.apply(lambda x: new_names[x['State name']] if x['State name'].upper() in new_names.keys()
                                    else x['State name'], axis=1)
# Out:
# C:\Users\miles.MILE-BL-4766-LA.000\AppData\Local\Temp\ipykernel_4176\1625868850.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dist_pop['State name'] =  df_dist_pop.apply(lambda x: new_names[x['State name']] if x['State name'].upper() in new_names.keys()

# %%
df_dist_pop.isna().sum()
# Out:
# District name        0
# Population          30
# Rural_Households    42
# Urban_Households    33
# State name           0
# dtype: int64

# %%
df_dist_pop = df_dist_pop.fillna(0)
df_dist_pop.head()
# Out:
#   District name  Population  Rural_Households  Urban_Households  \
# 0       Kupwara    870354.0          158438.0               0.0
# 1        Badgam    753745.0          160649.0           27190.0
# 2   Leh(Ladakh)    133487.0           36920.0           17474.0
# 3        Kargil    140802.0           40370.0            7774.0
# 4         Punch         0.0          132139.0           15269.0
#
#           State name
# 0  JAMMU AND KASHMIR
# 1  JAMMU AND KASHMIR
# 2  JAMMU AND KASHMIR
# 3  JAMMU AND KASHMIR
# 4  JAMMU AND KASHMIR

# %%
df_dist_pop[(df_dist_pop['Population'] == 0) & (df_dist_pop['Rural_Households'] == 0) & (df_dist_pop['Urban_Households'] == 0)]
# df_dist_pop[(df_dist_pop['Rural_Households'] == 0) & (df_dist_pop['Urban_Households'] == 0)],
# df_dist_pop[(df_dist_pop['Population'] == 0) & (df_dist_pop['Rural_Households'] == 0)]
# Out:
#     District name  Population  Rural_Households  Urban_Households  \
# 460       Anuppur         0.0               0.0               0.0
#
#          State name
# 460  MADHYA PRADESH

# %%
# calculating population from rual and urban households values
df_dist_pop['Population'] = df_dist_pop.apply(lambda x: x['Rural_Households']+x['Urban_Households'] if not x['Population']
                            else x['Population'], axis=1)

# calculating rural households from total population and urban households values
df_dist_pop['Rural_Households'] = df_dist_pop.apply(lambda x: x['Population'] - x['Urban_Households'] if not x['Rural_Households']
                            else x['Rural_Households'], axis=1)

# calculating urban households from total population and rural poplation
df_dist_pop['Urban_Households'] = df_dist_pop.apply(lambda x: x['Population'] - x['Rural_Households'] if not x['Urban_Households']
                            else x['Urban_Households'], axis=1)

# %%
df_housing['District Name'].nunique(),df_dist_pop['District name'].nunique()
# Out:
# (634, 634)

# %%
df_dist_pop.head()
# Out:
#   District name  Population  Rural_Households  Urban_Households  \
# 0       Kupwara    870354.0          158438.0          711916.0
# 1        Badgam    753745.0          160649.0           27190.0
# 2   Leh(Ladakh)    133487.0           36920.0           17474.0
# 3        Kargil    140802.0           40370.0            7774.0
# 4         Punch    147408.0          132139.0           15269.0
#
#           State name
# 0  JAMMU AND KASHMIR
# 1  JAMMU AND KASHMIR
# 2  JAMMU AND KASHMIR
# 3  JAMMU AND KASHMIR
# 4  JAMMU AND KASHMIR

# %%
# df_housing['Total_households'] 
# df_housing.apply(lambda x: df_dist_pop[df_dist_pop['District name']==x['District Name']]['Population'], axis=1)
total_pop = []
livable = []
dilapidated = []
latrine_prem = []
# "Total Number of households"	"Total Number of Livable"	"Total Number of Dilapidated"	"Latrine_premise"

ru = {'Rural':'Rural_Households', 'Urban':'Urban_Households', 'Total':'Population'}
stats_not_in_census = set()
for i in range(df_housing.shape[0]): #[['District Name','State Name']]:
    d = df_housing['District Name'][i]
    s = df_housing['State Name'][i]
    ur = df_housing['Rural/Urban'][i]

    temp = df_dist_pop[(df_dist_pop['District name']==d) & (df_dist_pop['State name']==s)]
    

    if len(temp) > 0:
        # tpop = temp[ru[ur]].iloc[0]
        total_pop.append(temp[ru[ur]].iloc[0])
        livable.append(temp[ru[ur]].iloc[0] * df_housing['Total Number of Livable'][i] / 100)
        dilapidated.append(temp[ru[ur]].iloc[0] * df_housing['Total Number of Dilapidated'][i] / 100)
        latrine_prem.append(temp[ru[ur]].iloc[0] * df_housing['Latrine_premise'][i] / 100)
    else:
        total_pop.append(0)
        livable.append(0)
        dilapidated.append(0)
        latrine_prem.append(0)
        stats_not_in_census.add(df_housing['District Name'][i])

# %%
len(stats_not_in_census)
# len(total_pop),len(latrine_prem),len(livable),len(dilapidated),df_housing.shape
# Out:
# 5

# %%
df_housing['Total_population'] = total_pop
df_housing["Livablle_value"] = livable
df_housing["Dilapidated_value"] = dilapidated
df_housing['Latrine_prem_value'] = latrine_prem
df_housing.head()
# Out:
#           State Name District Name Rural/Urban  Total Number of households  \
# 0  JAMMU AND KASHMIR       Kupwara       Rural                         100
# 1  JAMMU AND KASHMIR       Kupwara       Total                         100
# 2  JAMMU AND KASHMIR       Kupwara       Urban                         100
# 3  JAMMU AND KASHMIR        Badgam       Rural                         100
# 4  JAMMU AND KASHMIR        Badgam       Total                         100
#
#    Total Number of Livable  Total Number of Dilapidated  Latrine_premise  \
# 0                     58.1                          8.3             48.9
# 1                     57.3                          7.9             50.9
# 2                     49.5                          4.8             70.2
# 3                     46.3                          3.9             83.3
# 4                     44.7                          3.8             84.3
#
#    Total_population  Livablle_value  Dilapidated_value  Latrine_prem_value
# 0          158438.0       92052.478          13150.354           77476.182
# 1          870354.0      498712.842          68757.966          443010.186
# 2          711916.0      352398.420          34171.968          499765.032
# 3          160649.0       74380.487           6265.311          133820.617
# 4          753745.0      336924.015          28642.310          635407.035

# %% [markdown]
# ### Problem Statement 8: (Visualise the housing data)

# %%
# Visualize the following data for each state using appropriate methods:
# Number of households for 100 people
# Percentage of households that have toilet(s) in premise to the total number of households.
# Urban to rural population ratio.

# %%
df_housing_all = pd.read_csv("../Data/housing.csv")
df_housing_all.head(3)
# Out:
#    State Code       State Name  District Code District Name  Tehsil Code  \
# 0           1  JAMMU & KASHMIR              1       Kupwara            0
# 1           1  JAMMU & KASHMIR              1       Kupwara            0
# 2           1  JAMMU & KASHMIR              1       Kupwara            0
#
#   Tehsil Name  Town Code/Village code  Ward No           Area Name  \
# 0     Kupwara                       0        0  District - Kupwara
# 1     Kupwara                       0        0  District - Kupwara
# 2     Kupwara                       0        0  District - Kupwara
#
#   Rural/Urban  ...  Contition_T_Total  Contition_T_Good  Contition_T_Livable  \
# 0       Rural  ...                100              33.6                 58.1
# 1       Total  ...                100              34.8                 57.3
# 2       Urban  ...                100              45.7                 49.5
#
#    Contition_T_Dilapidated  Contition_R_Total  Residence_Good  \
# 0                      8.3               90.9            32.7
# 1                      7.9               91.0            33.8
# 2                      4.8               91.8            45.0
#
#    Residence_Livable  Residence_Dilapidated  Residence_cum_other  \
# 0               51.0                    7.2                  9.1
# 1               50.2                    6.9                  9.0
# 2               42.2                    4.5                  8.2
#
#    Residence_cum_Good
# 0                 1.0
# 1                 0.9
# 2                 0.7
#
# [3 rows x 156 columns]

# %%
# Percentage of households that have toilet(s) in premise to the total number of households.
# c100,Number of households not having latrine facility within the premises

# taking required cols and creating a temp dataframe
df_hs_temp = df_housing_all.iloc[:,[1,3,9,99]]

# adding population colm
df_hs_temp['Population'] = total_pop
df_hs_temp.head()
# Out:
# C:\Users\miles.MILE-BL-4766-LA.000\AppData\Local\Temp\ipykernel_4176\32335102.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hs_temp['Population'] = total_pop
#         State Name District Name Rural/Urban  H_latrine_premoses  Population
# 0  JAMMU & KASHMIR       Kupwara       Rural                51.1    158438.0
# 1  JAMMU & KASHMIR       Kupwara       Total                49.1    870354.0
# 2  JAMMU & KASHMIR       Kupwara       Urban                29.8    711916.0
# 3  JAMMU & KASHMIR        Badgam       Rural                16.7    160649.0
# 4  JAMMU & KASHMIR        Badgam       Total                15.7    753745.0

# %%
# total pop = rural pop + urban pop
# for every district taking only row corresponds to 'total' under Rural/Urban
df_hs_temp =  df_hs_temp[df_hs_temp['Rural/Urban'] == 'Total']
df_hs_temp.head()
# Out:
#          State Name District Name Rural/Urban  H_latrine_premoses  Population
# 1   JAMMU & KASHMIR       Kupwara       Total                49.1    870354.0
# 4   JAMMU & KASHMIR        Badgam       Total                15.7    753745.0
# 7   JAMMU & KASHMIR   Leh(Ladakh)       Total                 9.6    133487.0
# 10  JAMMU & KASHMIR        Kargil       Total                 3.1    140802.0
# 13  JAMMU & KASHMIR         Punch       Total                81.3    147408.0

# %%
# finding the actual values for h_latrine_premoses using population - pop who has no on premises toilets

df_hs_temp['H_latrine_premoses_values'] = df_hs_temp.apply(lambda x: round(x['H_latrine_premoses']*x['Population']/100), axis=1)
df_hs_temp.head()
# Out:
#          State Name District Name Rural/Urban  H_latrine_premoses  Population  \
# 1   JAMMU & KASHMIR       Kupwara       Total                49.1    870354.0
# 4   JAMMU & KASHMIR        Badgam       Total                15.7    753745.0
# 7   JAMMU & KASHMIR   Leh(Ladakh)       Total                 9.6    133487.0
# 10  JAMMU & KASHMIR        Kargil       Total                 3.1    140802.0
# 13  JAMMU & KASHMIR         Punch       Total                81.3    147408.0
#
#     H_latrine_premoses_values
# 1                      427344
# 4                      118338
# 7                       12815
# 10                       4365
# 13                     119843

# %%
# finding values for new col - T_on_premises - pop who has on premises toilets
df_hs_temp['T_On_premises'] = df_hs_temp.apply(lambda x: round((100-x['H_latrine_premoses'])*x['Population']/100), axis=1)
df_hs_temp.head(3)
# Out:
#         State Name District Name Rural/Urban  H_latrine_premoses  Population  \
# 1  JAMMU & KASHMIR       Kupwara       Total                49.1    870354.0
# 4  JAMMU & KASHMIR        Badgam       Total                15.7    753745.0
# 7  JAMMU & KASHMIR   Leh(Ladakh)       Total                 9.6    133487.0
#
#    H_latrine_premoses_values  T_On_premises
# 1                     427344         443010
# 4                     118338         635407
# 7                      12815         120672

# %%
df_hs_temp['Population'].sum(),df_hs_temp['T_On_premises'].sum()
# Out:
# (1150935278.0, 523796533)

# %%
# sum of population and T_on_premises(toilets on premises) group by state name
df_hs_st = df_hs_temp.groupby('State Name').sum(['Populations','T_On_premises'])
df_hs_st
# Out:
#                            H_latrine_premoses   Population  \
# State Name
# ANDAMAN & NICOBAR ISLANDS                92.5     122374.0
# ANDHRA PRADESH                         1218.0   81539713.0
# ARUNACHAL PRADESH                       654.0    1311346.0
# ASSAM                                  1013.1   29376658.0
# BIHAR                                  2936.4  101925629.0
# CHANDIGARH                               12.4    1055450.0
# CHHATTISGARH                           1424.6   25545198.0
# DADRA & NAGAR HAVELI                     45.3          0.0
# DAMAN & DIU                              58.8     243247.0
# GOA                                      40.3    1458545.0
# GUJARAT                                1314.7   54981981.0
# HARYANA                                 697.4   23800497.0
# HIMACHAL PRADESH                        370.6    6833038.0
# JAMMU & KASHMIR                        1076.4   12211875.0
# JHARKHAND                              1969.1   31886120.0
# KARNATAKA                              1669.0   59731378.0
# KERALA                                   76.9   33406061.0
# LAKSHADWEEP                               2.2          0.0
# MADHYA PRADESH                         3705.6   69001515.0
# MAHARASHTRA                            1803.8   90925180.0
# MANIPUR                                 138.5    2855794.0
# MEGHALAYA                               262.3    2864198.0
# MIZORAM                                  79.2    1097206.0
# NAGALAND                                296.1    1978502.0
# NCT OF DELHI                             99.2   16787941.0
# ODISHA                                 2411.7   41974218.0
# PUDUCHERRY                               91.2     297664.0
# PUNJAB                                  434.1   27189373.0
# RAJASTHAN                              2262.1   63668225.0
# SIKKIM                                   61.3     610577.0
# TAMIL NADU                             1790.0   72147030.0
# TRIPURA                                  70.1    3673917.0
# UTTAR PRADESH                          4739.5  195665580.0
# UTTARAKHAND                             525.7   10086292.0
# WEST BENGAL                             878.1   84682956.0
#
#                            H_latrine_premoses_values  T_On_premises
# State Name
# ANDAMAN & NICOBAR ISLANDS                      25597          96777
# ANDHRA PRADESH                              41892976       39646737
# ARUNACHAL PRADESH                             471815         839531
# ASSAM                                       10398018       18978640
# BIHAR                                       78041454       23884175
# CHANDIGARH                                    130876         924574
# CHHATTISGARH                                19230506        6314692
# DADRA & NAGAR HAVELI                               0              0
# DAMAN & DIU                                    55100         188147
# GOA                                           295938        1162607
# GUJARAT                                     23561158       31420823
# HARYANA                                      7808769       15991728
# HIMACHAL PRADESH                             2134850        4698188
# JAMMU & KASHMIR                              5469498        6742377
# JHARKHAND                                   24834493        7051627
# KARNATAKA                                   30435016       29296362
# KERALA                                       1582385       31823676
# LAKSHADWEEP                                        0              0
# MADHYA PRADESH                              48374779       20626736
# MAHARASHTRA                                 45167281       45757899
# MANIPUR                                       386869        2468925
# MEGHALAYA                                    1078773        1785425
# MIZORAM                                        90139        1007067
# NAGALAND                                      470538        1507964
# NCT OF DELHI                                 1746926       15041015
# ODISHA                                      32592303        9381915
# PUDUCHERRY                                     89875         207789
# PUNJAB                                       5696516       21492857
# RAJASTHAN                                   40779150       22889075
# SIKKIM                                         78610         531967
# TAMIL NADU                                  37342429       34804601
# TRIPURA                                       517070        3156847
# UTTAR PRADESH                              127479687       68185893
# UTTARAKHAND                                  3379939        6706353
# WEST BENGAL                                 35499412       49183544

# %%
# ploting population percentage for each state who has toilets on premises
df_hs_st.apply(lambda x: round(x['T_On_premises']/x['Population'] * 100,2) if x['Population']>0 
                                                else 0, axis=1).plot(kind='bar',layout=[12,24],figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='State Name'>

# %%
# Visualize the following data for each state using appropriate methods:
# Urban to rural population ratio.

# %%
df_dist_pop.head()
# Out:
#   District name  Population  Rural_Households  Urban_Households  \
# 0       Kupwara    870354.0          158438.0          711916.0
# 1        Badgam    753745.0          160649.0           27190.0
# 2   Leh(Ladakh)    133487.0           36920.0           17474.0
# 3        Kargil    140802.0           40370.0            7774.0
# 4         Punch    147408.0          132139.0           15269.0
#
#           State name
# 0  JAMMU AND KASHMIR
# 1  JAMMU AND KASHMIR
# 2  JAMMU AND KASHMIR
# 3  JAMMU AND KASHMIR
# 4  JAMMU AND KASHMIR

# %%
df_dist_pop.apply(lambda x: x['Population'] - x['Rural_Households'] + x['Urban_Households'], axis=1)
# Out:
# 0      1423832.0
# 1       620286.0
# 2       114041.0
# 3       108206.0
# 4        30538.0
#          ...
# 635      24220.0
# 636     198319.0
# 637      41768.0
# 638      67600.0
# 639     101262.0
# Length: 640, dtype: float64

# %%
# Urban to rural population ratio.
df_dist_pop.groupby('State name').sum().apply(lambda x: x['Urban_Households']/x['Rural_Households'], axis=1).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='State name'>

# %%
# Urban to rural population ratio. with out chandigarh
df_dist_pop[df_dist_pop['State name'] != 'CHANDIGARH'].groupby('State name').sum().apply(lambda x: x['Urban_Households']/x['Rural_Households'], axis=1).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='State name'>
